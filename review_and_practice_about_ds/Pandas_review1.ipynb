# %%
import numpy as np
import pandas as pd

# %%
data=pd.Series(np.random.randint(10,size=5))
data
# Out:
# 0    8
# 1    6
# 2    8
# 3    0
# 4    2
# dtype: int32

# %%
data=pd.Series(np.random.randint(10,size=5),index=['a','b','c','d','e'])
data
# Out:
# a    9
# b    4
# c    4
# d    2
# e    7
# dtype: int32

# %%
data.index,data.values
# Out:
# (Index(['a', 'b', 'c', 'd', 'e'], dtype='object'), array([9, 4, 4, 2, 7]))

# %%
data.a,data.b
# Out:
# (9, 4)

# %%
data[data>3]
# Out:
# a    9
# b    4
# c    4
# e    7
# dtype: int32

# %%
for idx,val in data.items():
    print(idx,val)
# Out:
# a 9
# b 4
# c 4
# d 2
# e 7

# %%
dic={'A':7,'E':1,'D':5}
s=pd.Series(dic)
s
# Out:
# A    7
# D    5
# E    1
# dtype: int64

# %%
dic={'A':1,'B':4,'E':5}
data=pd.Series(dic)
data
# Out:
# A    1
# B    4
# E    5
# dtype: int64

# %%
result=data+s
result
# Out:
# A    8.0
# B    NaN
# D    NaN
# E    6.0
# dtype: float64

# %%
result=result[result.notnull()]
result
# Out:
# A    8.0
# E    6.0
# dtype: float64

# %%
df=pd.DataFrame(columns=['email','name'])
df['name']=['hello','world']
df['email']=['youdonthaveto','knowthat']
df
# Out:
#            email   name
# 0  youdonthaveto  hello
# 1       knowthat  world

# %%
name=['kim','lee']
email=['hello','world']
dic={'Email':email,'Name':name}
df=pd.DataFrame(dic)
df
# Out:
#    Email Name
# 0  hello  kim
# 1  world  lee

# %%
index=['Im','king']
dic={'Email':email,'Name':name}
df=pd.DataFrame(dic,index=index)
df
# Out:
#       Email Name
# Im    hello  kim
# king  world  lee

# %%
df.index,df.columns,df.values
# Out:
# (Index(['Im', 'king'], dtype='object'),
#  Index(['Email', 'Name'], dtype='object'),
#  array([['hello', 'kim'],
#         ['world', 'lee']], dtype=object))

# %%
data = {"Email": ["fcamp@gmail.com", "dss@gmail.com"], "Name": ["fcamp", "dss"]}
df = pd.DataFrame(data)
df
# Out:
#              Email   Name
# 0  fcamp@gmail.com  fcamp
# 1    dss@gmail.com    dss

# %%
df.loc[1]#row indexing
# Out:
# Email    dss@gmail.com
# Name               dss
# Name: 1, dtype: object

# %%
df['Email'] #col indexing
# Out:
# 0    fcamp@gmail.com
# 1      dss@gmail.com
# Name: Email, dtype: object

# %%
df.loc[2] = {'Email':'helloworld@gmail.com','Name':'helloworld'}
df
# Out:
#                   Email        Name
# 0       fcamp@gmail.com       fcamp
# 1         dss@gmail.com         dss
# 2  helloworld@gmail.com  helloworld

# %%
df.loc[len(df)]={"Email":"science@gmail.com", "Name":"science"}
df
# Out:
#                   Email        Name
# 0       fcamp@gmail.com       fcamp
# 1         dss@gmail.com         dss
# 2  helloworld@gmail.com  helloworld
# 3     science@gmail.com     science

# %%
df['Address']=0
df
# Out:
#                   Email        Name  Address
# 0       fcamp@gmail.com       fcamp        0
# 1         dss@gmail.com         dss        0
# 2  helloworld@gmail.com  helloworld        0
# 3     science@gmail.com     science        0

# %%
df['Address']=['a','b','c','d']
df
# Out:
#                   Email        Name Address
# 0       fcamp@gmail.com       fcamp       a
# 1         dss@gmail.com         dss       b
# 2  helloworld@gmail.com  helloworld       c
# 3     science@gmail.com     science       d

# %%
def name(name):
    return "{}({})".format(name,len(name))
df['New name']=df['Name'].apply(name)
df
# Out:
#                   Email        Name Address        New name
# 0       fcamp@gmail.com       fcamp       a        fcamp(5)
# 1         dss@gmail.com         dss       b          dss(3)
# 2  helloworld@gmail.com  helloworld       c  helloworld(10)
# 3     science@gmail.com     science       d      science(7)

# %%
df['New Address']=df['Address'].apply(lambda addr: '{}({})'.format(addr, len(addr)))
df
# Out:
#                   Email        Name Address        New name New Address
# 0       fcamp@gmail.com       fcamp       a        fcamp(5)        a(1)
# 1         dss@gmail.com         dss       b          dss(3)        b(1)
# 2  helloworld@gmail.com  helloworld       c  helloworld(10)        c(1)
# 3     science@gmail.com     science       d      science(7)        d(1)

# %%
import random,string

def get_name():
    names=['Adam', 'Alan', 'Alex', 'Alvin', 'Andrew', 'Anthony', 'Arnold', 'Baldy','Caley','Champ','Charile']
    return random.choice(names)
def get_age(start=20,end=40):
    return random.randint(start,end)
def make_data(rows=10):
    datas=[]
    for _ in range(rows):
        data={'age':get_age(),'name':get_name()}
        datas.append(data)
    return datas

# %%
make_data()
# Out:
# [{'age': 24, 'name': 'Caley'},
#  {'age': 32, 'name': 'Alvin'},
#  {'age': 29, 'name': 'Andrew'},
#  {'age': 39, 'name': 'Alvin'},
#  {'age': 34, 'name': 'Charile'},
#  {'age': 31, 'name': 'Adam'},
#  {'age': 21, 'name': 'Adam'},
#  {'age': 28, 'name': 'Arnold'},
#  {'age': 27, 'name': 'Caley'},
#  {'age': 22, 'name': 'Baldy'}]

# %%
data1=make_data()
df1=pd.DataFrame(data1)
df1
# Out:
#    age     name
# 0   23  Anthony
# 1   31    Caley
# 2   36   Andrew
# 3   31     Alan
# 4   30    Caley
# 5   21   Andrew
# 6   30     Alan
# 7   34   Andrew
# 8   23  Charile
# 9   24    Alvin

# %%
data2=make_data()
df2=pd.DataFrame(data2)
df2
# Out:
#    age     name
# 0   26    Alvin
# 1   24    Caley
# 2   22   Arnold
# 3   35  Charile
# 4   25  Charile
# 5   34   Andrew
# 6   38     Alan
# 7   26     Alan
# 8   30  Anthony
# 9   40    Alvin

# %%
df3=df1.append(df2)
df3
# Out:
#    age     name
# 0   23  Anthony
# 1   31    Caley
# 2   36   Andrew
# 3   31     Alan
# 4   30    Caley
# 5   21   Andrew
# 6   30     Alan
# 7   34   Andrew
# 8   23  Charile
# 9   24    Alvin
# 0   26    Alvin
# 1   24    Caley
# 2   22   Arnold
# 3   35  Charile
# 4   25  Charile
# 5   34   Andrew
# 6   38     Alan
# 7   26     Alan
# 8   30  Anthony
# 9   40    Alvin

# %%
df3.reset_index(drop=True,inplace=True)
df3
# Out:
#     age     name
# 0    23  Anthony
# 1    31    Caley
# 2    36   Andrew
# 3    31     Alan
# 4    30    Caley
# 5    21   Andrew
# 6    30     Alan
# 7    34   Andrew
# 8    23  Charile
# 9    24    Alvin
# 10   26    Alvin
# 11   24    Caley
# 12   22   Arnold
# 13   35  Charile
# 14   25  Charile
# 15   34   Andrew
# 16   38     Alan
# 17   26     Alan
# 18   30  Anthony
# 19   40    Alvin

# %%
df3=df1.append(df2,ignore_index=True)
df3
# Out:
#     age     name
# 0    23  Anthony
# 1    31    Caley
# 2    36   Andrew
# 3    31     Alan
# 4    30    Caley
# 5    21   Andrew
# 6    30     Alan
# 7    34   Andrew
# 8    23  Charile
# 9    24    Alvin
# 10   26    Alvin
# 11   24    Caley
# 12   22   Arnold
# 13   35  Charile
# 14   25  Charile
# 15   34   Andrew
# 16   38     Alan
# 17   26     Alan
# 18   30  Anthony
# 19   40    Alvin

# %%
df3=pd.concat([df1,df2]).reset_index(drop=True)
df3
# Out:
#     age     name
# 0    23  Anthony
# 1    31    Caley
# 2    36   Andrew
# 3    31     Alan
# 4    30    Caley
# 5    21   Andrew
# 6    30     Alan
# 7    34   Andrew
# 8    23  Charile
# 9    24    Alvin
# 10   26    Alvin
# 11   24    Caley
# 12   22   Arnold
# 13   35  Charile
# 14   25  Charile
# 15   34   Andrew
# 16   38     Alan
# 17   26     Alan
# 18   30  Anthony
# 19   40    Alvin

# %%
df4=pd.concat([df1,df2],axis=1,join='inner')
df4
# Out:
#    age     name  age     name
# 0   23  Anthony   26    Alvin
# 1   31    Caley   24    Caley
# 2   36   Andrew   22   Arnold
# 3   31     Alan   35  Charile
# 4   30    Caley   25  Charile
# 5   21   Andrew   34   Andrew
# 6   30     Alan   38     Alan
# 7   34   Andrew   26     Alan
# 8   23  Charile   30  Anthony
# 9   24    Alvin   40    Alvin

# %%
g_df=pd.DataFrame(make_data(20))
g_df.tail()
# Out:
#     age     name
# 15   27  Anthony
# 16   27    Baldy
# 17   27    Caley
# 18   31    Baldy
# 19   34    Champ

# %%
ls1=list(set(g_df['name'].values))
len(ls1)
# Out:
# 10

# %%
ls2=g_df['name'].unique()
len(ls2)
# Out:
# 10

# %%
result_df = g_df.groupby('name').size().reset_index(name='counts')
result_df
# Out:
#       name  counts
# 0     Alan       4
# 1     Alex       1
# 2    Alvin       1
# 3   Andrew       1
# 4  Anthony       2
# 5   Arnold       1
# 6    Baldy       4
# 7    Caley       2
# 8    Champ       1
# 9  Charile       3

# %%
result_df = result_df.sort_values(by=['counts'],ascending=False).reset_index(drop=True)
result_df
# Out:
#       name  counts
# 0     Alan       4
# 1    Baldy       4
# 2  Charile       3
# 3  Anthony       2
# 4    Caley       2
# 5     Alex       1
# 6    Alvin       1
# 7   Andrew       1
# 8   Arnold       1
# 9    Champ       1

# %%
g_df.groupby('name').agg('min').reset_index()
# Out:
#       name  age
# 0     Alan   24
# 1     Alex   37
# 2    Alvin   38
# 3   Andrew   25
# 4  Anthony   27
# 5   Arnold   25
# 6    Baldy   23
# 7    Caley   27
# 8    Champ   34
# 9  Charile   29

# %%
g_df.groupby('name').agg('max').reset_index()
# Out:
#       name  age
# 0     Alan   37
# 1     Alex   37
# 2    Alvin   38
# 3   Andrew   25
# 4  Anthony   29
# 5   Arnold   25
# 6    Baldy   31
# 7    Caley   33
# 8    Champ   34
# 9  Charile   33

# %%
g_df.groupby('name').agg('mean').reset_index()
# Out:
#       name        age
# 0     Alan  30.250000
# 1     Alex  37.000000
# 2    Alvin  38.000000
# 3   Andrew  25.000000
# 4  Anthony  28.000000
# 5   Arnold  25.000000
# 6    Baldy  26.250000
# 7    Caley  30.000000
# 8    Champ  34.000000
# 9  Charile  31.333333

# %%
g_df.groupby('name').agg('median').reset_index()
# Out:
#       name   age
# 0     Alan  30.0
# 1     Alex  37.0
# 2    Alvin  38.0
# 3   Andrew  25.0
# 4  Anthony  28.0
# 5   Arnold  25.0
# 6    Baldy  25.5
# 7    Caley  30.0
# 8    Champ  34.0
# 9  Charile  32.0

# %%
g_df.groupby('name').agg(['min','max','mean']).reset_index()
# Out:
#       name age
#            min max       mean
# 0     Alan  24  37  30.250000
# 1     Alex  37  37  37.000000
# 2    Alvin  38  38  38.000000
# 3   Andrew  25  25  25.000000
# 4  Anthony  27  29  28.000000
# 5   Arnold  25  25  25.000000
# 6    Baldy  23  31  26.250000
# 7    Caley  27  33  30.000000
# 8    Champ  34  34  34.000000
# 9  Charile  29  33  31.333333

# %%
df = _
df=df[::-1].reset_index(drop=True)
df
# Out:
#       name age
#            min max       mean
# 0     Alan  24  37  30.250000
# 1     Alex  37  37  37.000000
# 2    Alvin  38  38  38.000000
# 3   Andrew  25  25  25.000000
# 4  Anthony  27  29  28.000000
# 5   Arnold  25  25  25.000000
# 6    Baldy  23  31  26.250000
# 7    Caley  27  33  30.000000
# 8    Champ  34  34  34.000000
# 9  Charile  29  33  31.333333

# %%
data={
    'name':df['name'],
    'min':df['age']['min'],
    'max':df['age']['max'],
    'mean':df['age']['mean']
}
n_df=pd.DataFrame(data)
n_df
# Out:
#    max       mean  min     name
# 0   37  30.250000   24     Alan
# 1   37  37.000000   37     Alex
# 2   38  38.000000   38    Alvin
# 3   25  25.000000   25   Andrew
# 4   29  28.000000   27  Anthony
# 5   25  25.000000   25   Arnold
# 6   31  26.250000   23    Baldy
# 7   33  30.000000   27    Caley
# 8   34  34.000000   34    Champ
# 9   33  31.333333   29  Charile

# %%
n_df[n_df['mean']>30].sort_values(by=['mean'],ascending=False).reset_index(drop=True)
# Out:
#    max       mean  min     name
# 0   38  38.000000   38    Alvin
# 1   37  37.000000   37     Alex
# 2   34  34.000000   34    Champ
# 3   33  31.333333   29  Charile
# 4   37  30.250000   24     Alan

# %%
list(g_df.groupby('name').size())
# Out:
# [4, 1, 1, 1, 2, 1, 4, 2, 1, 3]

# %%
n_df['counts']=list(g_df.groupby('name').size())
n_df
# Out:
#    max       mean  min     name  counts
# 0   37  30.250000   24     Alan       4
# 1   37  37.000000   37     Alex       1
# 2   38  38.000000   38    Alvin       1
# 3   25  25.000000   25   Andrew       1
# 4   29  28.000000   27  Anthony       2
# 5   25  25.000000   25   Arnold       1
# 6   31  26.250000   23    Baldy       4
# 7   33  30.000000   27    Caley       2
# 8   34  34.000000   34    Champ       1
# 9   33  31.333333   29  Charile       3

# %%
n_df['mean'] = mean
n_df
# Out:
#    max  min     name  counts       mean
# 0   37   24     Alan       4  30.250000
# 1   37   37     Alex       1  37.000000
# 2   38   38    Alvin       1  38.000000
# 3   25   25   Andrew       1  25.000000
# 4   29   27  Anthony       2  28.000000
# 5   25   25   Arnold       1  25.000000
# 6   31   23    Baldy       4  26.250000
# 7   33   27    Caley       2  30.000000
# 8   34   34    Champ       1  34.000000
# 9   33   29  Charile       3  31.333333

# %%
n_df.rename(columns={'name':'rename','max':'Max'},inplace=True)
n_df.head(2)
# Out:
#    Max  min rename  counts   mean
# 0   37   24   Alan       4  30.25
# 1   37   37   Alex       1  37.00

# %%
# 중복되는 이름 없이 아이디, 이름, 나이 데이터가 포함된 데이터 프레임 생성
user_df = pd.DataFrame(columns=["UserID", "Name", "Age"])
for idx in range(1,11):
    name = get_name()
# 이름이 중복이면 다시 뽑기
    while name in list(user_df["Name"]):
        name = get_name()
# 데이터 name_df에 insert
    data = {"Name":name, "UserID":idx, "Age":get_age()}
    user_df.loc[len(user_df)] = data
user_df
# Out:
#   UserID     Name Age
# 0      1  Anthony  27
# 1      2     Adam  31
# 2      3    Caley  32
# 3      4    Champ  27
# 4      5     Alan  24
# 5      6   Andrew  37
# 6      7   Arnold  20
# 7      8    Baldy  37
# 8      9  Charile  38
# 9     10    Alvin  22

# %%
money_df = pd.DataFrame(columns=["ID","Money"])
for idx in range(15):
    money = random.randint(1,20) * 1000
    data = {"Money":money, "ID":random.randint(1,10)}
    money_df.loc[len(money_df)] = data
# money_df.sort_values("ID", inplace=True)
money_df
# Out:
#     ID  Money
# 0   10  12000
# 1    1  18000
# 2    9   7000
# 3    6  16000
# 4    3   4000
# 5    6   4000
# 6    5   7000
# 7    7  15000
# 8    7   1000
# 9    2   2000
# 10   7  17000
# 11   6   6000
# 12   3  20000
# 13   5   6000
# 14   9  11000

# %%
money_df.merge(user_df, left_on="ID", right_on="UserID")
# Out:
#     ID  Money UserID     Name Age
# 0   10  12000     10    Alvin  22
# 1    1  18000      1  Anthony  27
# 2    9   7000      9  Charile  38
# 3    9  11000      9  Charile  38
# 4    6  16000      6   Andrew  37
# 5    6   4000      6   Andrew  37
# 6    6   6000      6   Andrew  37
# 7    3   4000      3    Caley  32
# 8    3  20000      3    Caley  32
# 9    5   7000      5     Alan  24
# 10   5   6000      5     Alan  24
# 11   7  15000      7   Arnold  20
# 12   7   1000      7   Arnold  20
# 13   7  17000      7   Arnold  20
# 14   2   2000      2     Adam  31

# %%
user_df.rename(columns={'UserID':"ID"},inplace=True)
user_df
# Out:
#    ID     Name Age
# 0   1  Anthony  27
# 1   2     Adam  31
# 2   3    Caley  32
# 3   4    Champ  27
# 4   5     Alan  24
# 5   6   Andrew  37
# 6   7   Arnold  20
# 7   8    Baldy  37
# 8   9  Charile  38
# 9  10    Alvin  22

# %%
result_df=pd.merge(money_df,user_df)
result_df
# Out:
#     ID  Money     Name Age
# 0   10  12000    Alvin  22
# 1    1  18000  Anthony  27
# 2    9   7000  Charile  38
# 3    9  11000  Charile  38
# 4    6  16000   Andrew  37
# 5    6   4000   Andrew  37
# 6    6   6000   Andrew  37
# 7    3   4000    Caley  32
# 8    3  20000    Caley  32
# 9    5   7000     Alan  24
# 10   5   6000     Alan  24
# 11   7  15000   Arnold  20
# 12   7   1000   Arnold  20
# 13   7  17000   Arnold  20
# 14   2   2000     Adam  31

# %%
money_list = result_df.groupby('Name').sum()['Money'].reset_index()
money_list = money_list.sort_values(by=['Money'],ascending=False).reset_index(drop=True)
money_list
# Out:
#       Name  Money
# 0   Arnold  33000
# 1   Andrew  26000
# 2    Caley  24000
# 3  Anthony  18000
# 4  Charile  18000
# 5     Alan  13000
# 6    Alvin  12000
# 7     Adam   2000

# %%
result=pd.merge(user_df,money_list,how='outer').fillna(value=0)
result = result.sort_values(by=['Money'],ascending=False).reset_index(drop=True)
result['Money']=result['Money'].astype('int')
result
# Out:
#    ID     Name  Age  Money
# 0   7   Arnold   20  33000
# 1   6   Andrew   37  26000
# 2   3    Caley   32  24000
# 3   1  Anthony   27  18000
# 4   9  Charile   38  18000
# 5   5     Alan   24  13000
# 6  10    Alvin   22  12000
# 7   2     Adam   31   2000
# 8   4    Champ   27      0
# 9   8    Baldy   37      0
