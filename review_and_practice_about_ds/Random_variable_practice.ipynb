# %%
import scipy as sp
import matplotlib.pylab as plt
import seaborn as sns

# %%
rv=sp.stats.norm()
rv

# %%
rv=sp.stats.norm(loc=1,scale=2)

# %%
ls=rv.rvs(1000)
np.mean(ls),np.std(ls)
# Out:
# (0.9402722077571909, 1.980830082482312)

# %% [markdown]
# If N is getter larger, and mean and std tend to close with location and scale variable which I allocated.

# %%
xx=np.linspace(-8,8,100)
pdf = rv.pdf(xx)
plt.figure(figsize=(4,2))
plt.plot(xx,pdf)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
xx=np.linspace(-8,8,100)
cdf = rv.cdf(xx)
plt.figure(figsize=(4,2))
plt.plot(xx,cdf)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
rv.rvs(size=10,random_state=0)
# Out:
# array([ 4.52810469,  1.80031442,  2.95747597,  5.4817864 ,  4.73511598,
#        -0.95455576,  2.90017684,  0.69728558,  0.7935623 ,  1.821197  ])

# %%
plt.figure(figsize=(4,2))
sns.distplot(rv.rvs(size=1000,random_state=0))
plt.xlim(-8,8)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
theta=0.6
rv=sp.stats.bernoulli(theta)

# %%
xx=[0,1]
plt.figure(figsize=(4,2))
plt.bar(xx,rv.pmf(xx))
plt.xlim(-1,2)
plt.ylim(0,1)
plt.xticks([0,1],['x=0','x=1'])
plt.xlabel('sample')
plt.ylabel('P(x)')
plt.title('pmf of bernoulli random variable')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
x=rv.rvs(1000,random_state=0)

# %%
plt.figure(figsize=(4,2))
sns.countplot(x)
plt.title('simulation of bernoulli random variable')
plt.xlabel('sample')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
y = np.bincount(x,minlength =2)/float(len(x))
df = pd.DataFrame({'theory':rv.pmf(xx),'simulation':y})
df['parameter']=['(1-theta)','(theta)']
df.set_index(['parameter'],drop=True,inplace=True)
df
# Out:
#            simulation  theory
# parameter
# (1-theta)        0.39     0.4
# (theta)          0.61     0.6

# %%
df2=df.stack().reset_index()
df2.columns=['paramter','type','probability']
df2
# Out:
#     paramter        type  probability
# 0  (1-theta)  simulation         0.39
# 1  (1-theta)      theory         0.40
# 2    (theta)  simulation         0.61
# 3    (theta)      theory         0.60

# %%
plt.figure(figsize=(4,2))
sns.barplot(x='paramter',y='probability',hue='type',data=df2)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
N=10
theta = 0.6
rv=sp.stats.binom(N,theta)
rv

# %%
N1=5
theta1 = 0.5
rv1=sp.stats.binom(N1,theta1)
rv1

# %%
N2=20
theta2 = 0.9
rv2=sp.stats.binom(N2,theta2)
rv2

# %%
x=rv1.rvs(100,random_state=0)
xx=np.arange(N1+1)

# %%
y=np.bincount(x,minlength=N1+1)/float(len(x))
df=pd.DataFrame({'theory':rv1.pmf(xx),'simulation':y}).stack()
df=df.reset_index()
df.columns=['sample','type','ratio']
df.pivot('sample','type','ratio')
df[:6]
# Out:
#    sample        type    ratio
# 0       0  simulation  0.04000
# 1       0      theory  0.03125
# 2       1  simulation  0.20000
# 3       1      theory  0.15625
# 4       2  simulation  0.27000
# 5       2      theory  0.31250

# %%
plt.figure(figsize=(4,2))
sns.barplot(x="sample", y="ratio", hue="type", data=df)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
x=rv2.rvs(100,random_state=0)
xx=np.arange(N2+1)

# %%
y=np.bincount(x,minlength=N2+1)/float(len(x))
df=pd.DataFrame({'theory':rv2.pmf(xx),'simulation':y}).stack()
df=df.reset_index()
df.columns=['sample','type','ratio']
df.pivot('sample','type','ratio')
df[:6]
# Out:
#    sample        type         ratio
# 0       0  simulation  0.000000e+00
# 1       0      theory  1.000000e-20
# 2       1  simulation  0.000000e+00
# 3       1      theory  1.800000e-18
# 4       2  simulation  0.000000e+00
# 5       2      theory  1.539000e-16

# %%
plt.figure(figsize=(4,2))
sns.barplot(x="sample", y="ratio", hue="type", data=df)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
xx=np.arange(N+1)
x=rv1.rvs(1000)
plt.figure(figsize=(4,2))
plt.bar(xx,rv.pmf(xx),align='center')
plt.ylabel('P(x)')
plt.title('pmf of binomial distribution')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
xx=np.arange(N1+1)
plt.figure(figsize=(4,2))
plt.bar(xx,rv1.pmf(xx),align='center')
plt.bar(xx)
plt.ylabel('P(x)')
plt.title('pmf of binomial distribution1')
plt.show()
print('binomial distribution theta:{} N:{}'.format(theta1,N1))
# Out:
# <img src="data:image/png;base64,..." width="400">
# binomial distribution theta:0.5 N:5

# %%
xx=np.arange(N2+1)
plt.figure(figsize=(4,2))
plt.bar(xx,rv2.pmf(xx),align='center')
plt.ylabel('P(x)')
plt.title('pmf of binomial distribution2')
plt.show()
print('binomial distribution theta:{} N:{}'.format(theta2,N2))
# Out:
# <img src="data:image/png;base64,..." width="400">
# binomial distribution theta:0.9 N:20

# %%
x=rv.rvs(100,random_state=0)

# %%
plt.figure(figsize=(4,2))
sns.countplot(x)
plt.title('simulation of binomial distribution')
plt.xlabel('sample')
plt.ylabel('counts')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
y=np.bincount(x,minlength=N+1)/float(len(x))
df=pd.DataFrame({'theory':rv.pmf(xx),'simulation':y}).stack()
df=df.reset_index()
df.columns=['sample','type','ratio']
df.pivot('sample','type','ratio')
df[:6]
# Out:
#    sample        type     ratio
# 0       0  simulation  0.000000
# 1       0      theory  0.000105
# 2       1  simulation  0.000000
# 3       1      theory  0.001573
# 4       2  simulation  0.010000
# 5       2      theory  0.010617

# %%
y=np.bincount(x,minlength=N1+1)/float(len(x))
df=pd.DataFrame({'theory':rv.pmf(xx),'simulation':y}).stack()
df=df.reset_index()
df.columns=['sample','type','ratio']
df.pivot('sample','type','ratio')
df[:6]

# %%
y=np.bincount(x,minlength=N2+1)/float(len(x))
df=pd.DataFrame({'theory':rv.pmf(xx),'simulation':y}).stack()
df=df.reset_index()
df.columns=['sample','type','ratio']
df.pivot('sample','type','ratio')
df[:6]

# %%
plt.figure(figsize=(4,2))
sns.barplot(x="sample", y="ratio", hue="type", data=df)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
mu = 0
std =1
rv = sp.stats.norm(mu,std)

# %%
xx= np.linspace(-5,5,100)
plt.plot(xx,rv.pdf(xx))
plt.title('정규 분포의 확률 밀도 함수(pdf)')
plt.ylabel('P(x)')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
np.random.seed(0)
x = rv.rvs(100)
x
# Out:
# array([ 1.76405235,  0.40015721,  0.97873798,  2.2408932 ,  1.86755799,
#        -0.97727788,  0.95008842, -0.15135721, -0.10321885,  0.4105985 ,
#         0.14404357,  1.45427351,  0.76103773,  0.12167502,  0.44386323,
#         0.33367433,  1.49407907, -0.20515826,  0.3130677 , -0.85409574,
#        -2.55298982,  0.6536186 ,  0.8644362 , -0.74216502,  2.26975462,
#        -1.45436567,  0.04575852, -0.18718385,  1.53277921,  1.46935877,
#         0.15494743,  0.37816252, -0.88778575, -1.98079647, -0.34791215,
#         0.15634897,  1.23029068,  1.20237985, -0.38732682, -0.30230275,
#        -1.04855297, -1.42001794, -1.70627019,  1.9507754 , -0.50965218,
#        -0.4380743 , -1.25279536,  0.77749036, -1.61389785, -0.21274028,
#        -0.89546656,  0.3869025 , -0.51080514, -1.18063218, -0.02818223,
#         0.42833187,  0.06651722,  0.3024719 , -0.63432209, -0.36274117,
#        -0.67246045, -0.35955316, -0.81314628, -1.7262826 ,  0.17742614,
# ...

# %%
sns.distplot(x, kde=True, fit=sp.stats.norm)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
np.random.seed(0)
x = np.random.randn(1000)
plt.figure(figsize=(5, 5))
sp.stats.probplot(x, plot=plt)
plt.axis("equal")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
np.random.seed(0)
x = np.random.rand(10000)
plt.figure(figsize=(5, 5))
sp.stats.probplot(x, plot=plt)
plt.ylim(-0.5, 1.5)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
np.random.seed(0)
xx = np.linspace(-2, 2, 100)
plt.figure(figsize=(6, 9))
for i, N in enumerate([1, 2, 20]):
    X = np.random.rand(5000, N)
    Xbar = (X.mean(axis=1) - 0.5) * np.sqrt(12 * N)
    ax = plt.subplot(3, 2, 2 * i + 1)
    sns.distplot(Xbar, bins=10, kde=False, norm_hist=True)
    plt.xlim(-5, 5)
    plt.yticks([])
    ax.set_title("N = {0}".format(N))
    plt.subplot(3, 2, 2 * i + 2)
    sp.stats.probplot(Xbar, plot=plt)

plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
x1=np.random.rand(100)
x2=np.random.rand(100)
x3=x1+x2

# %%
plt.figure(figsize=(4,2))
sns.distplot(x1,kde=False)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
plt.figure(figsize=(4,2))
sns.distplot(x2,kde=False)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
plt.figure(figsize=(4,2))
sns.distplot(x3,kde=False)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
plt.figure(figsize=(3, 3))
sp.stats.probplot(x1, plot=plt)
plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="300">

# %%
plt.figure(figsize=(3, 3))
sp.stats.probplot(x2, plot=plt)
plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="300">

# %%
plt.figure(figsize=(3, 3))
sp.stats.probplot(x3, plot=plt)
plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="300">
