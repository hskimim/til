# %%
import pandas as pd
import numpy as np
import requests
from pandas.io.json import json_normalize
import json
from selenium import webdriver

# %% [markdown]
# ##### 아래 URL의 NBA 데이터를 크롤링하여 판다스 데이터 프레임으로 나타내세요.
# - http://stats.nba.com/teams/traditional/?sort=GP&dir=-1

# %%
url = "https://stats.nba.com/stats/leaguedashteamstats?Conference=&DateFrom=&DateTo=&Division=&GameScope=&GameSegment=&LastNGames=0&LeagueID=00&Location=&MeasureType=Base&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PaceAdjust=N&PerMode=PerGame&Period=0&PlayerExperience=&PlayerPosition=&PlusMinus=N&Rank=N&Season=2017-18&SeasonSegment=&SeasonType=Regular+Season&ShotClockRange=&StarterBench=&TeamID=0&VsConference=&VsDivision="
headers ={'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.87 Safari/537.36'}

# %%
re = requests.get(url,headers=headers)
jo = json.loads(re.text)

# %%
col = jo['resultSets'][0]['headers']
len(col),col
# Out:
# (56,
#  ['TEAM_ID',
#   'TEAM_NAME',
#   'GP',
#   'W',
#   'L',
#   'W_PCT',
#   'MIN',
#   'FGM',
#   'FGA',
#   'FG_PCT',
#   'FG3M',
#   'FG3A',
#   'FG3_PCT',
#   'FTM',
#   'FTA',
#   'FT_PCT',
#   'OREB',
#   'DREB',
#   'REB',
#   'AST',
#   'TOV',
#   'STL',
#   'BLK',
#   'BLKA',
#   'PF',
#   'PFD',
#   'PTS',
#   'PLUS_MINUS',
#   'GP_RANK',
#   'W_RANK',
#   'L_RANK',
#   'W_PCT_RANK',
#   'MIN_RANK',
#   'FGM_RANK',
#   'FGA_RANK',
#   'FG_PCT_RANK',
#   'FG3M_RANK',
#   'FG3A_RANK',
#   'FG3_PCT_RANK',
#   'FTM_RANK',
#   'FTA_RANK',
#   'FT_PCT_RANK',
#   'OREB_RANK',
#   'DREB_RANK',
#   'REB_RANK',
#   'AST_RANK',
#   'TOV_RANK',
#   'STL_RANK',
#   'BLK_RANK',
#   'BLKA_RANK',
#   'PF_RANK',
#   'PFD_RANK',
#   'PTS_RANK',
#   'PLUS_MINUS_RANK',
#   'CFID',
#   'CFPARAMS'])

# %%
NBA_df = pd.DataFrame(columns=col)
NBA_df
for i in range(len(info)):
    NBA_df.loc[len(NBA_df)] = info[i]
NBA_df.drop(columns=['PLUS_MINUS_RANK','TEAM_ID','CFPARAMS'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-cf03724f029d> in <module>()
#       1 NBA_df = pd.DataFrame(columns=col)
#       2 NBA_df
# ----> 3 for i in range(len(info)):
#       4     NBA_df.loc[len(NBA_df)] = info[i]
#       5 NBA_df.drop(columns=['PLUS_MINUS_RANK','TEAM_ID','CFPARAMS'],inplace=True)
#
# NameError: name 'info' is not defined

# %%
NBA_df
# Out:
#              TEAM_NAME  GP   W   L  W_PCT   MIN   FGM   FGA  FG_PCT  FG3M  \
# 25    Sacramento Kings  82  27  55  0.329  48.2  38.8  86.1   0.450   9.0
# 26   San Antonio Spurs  82  47  35  0.573  48.1  39.0  85.4   0.457   8.5
# 27     Toronto Raptors  82  59  23  0.720  48.4  41.3  87.4   0.472  11.8
# 28           Utah Jazz  82  48  34  0.585  48.2  38.3  82.9   0.462  10.8
# 29  Washington Wizards  82  43  39  0.524  48.4  39.9  85.6   0.467   9.9
#
#     ...   REB_RANK  AST_RANK  TOV_RANK  STL_RANK  BLK_RANK  BLKA_RANK  \
# 25  ...         28        25         9        11        25         14
# 26  ...         11        15         4        14         4          2
# 27  ...         14         6         6        18         2         18
# 28  ...         20        21        20         4         9         11
# 29  ...         21         4        18        10        22         13
#
#     PF_RANK  PFD_RANK  PTS_RANK  CFID
# 25       19        30        30    10
# 26        1        18        27    10
# 27       27        16         4    10
# 28       16         8        19    10
# 29       25        15        13    10
#
# [5 rows x 53 columns]

# %% [markdown]
# ##### 셀레니움을 이용하여 네이버 IT/과학 기사의 10 페이지 까지의 최신 제목 리스트를 크롤링하세요.
# - http://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=105

# %%
from selenium import webdriver
import time

# %%
def navertitle1(pageNum=10):
    driver = webdriver.Chrome()
    header = []
    for i in range(1,pageNum+1):
        url = 'http://news.naver.com/main/list.nhn?mode=LSD&mid=sec&listType=title&sid1=105&date=20180627&page={}'.format(i)
        driver.get(url)
        time.sleep(2)
        titles1 = driver.find_elements_by_css_selector('.type02 li')
        for title1 in titles1:
            header.append(title1.find_element_by_css_selector('a').text)
    driver.quit()
    return header

# %%
navertitle1()
# Out:
# ['[IT신상공개] 좋다는 것만 다 집어 넣은 느낌, 로지텍 G512 GX 블루 키보드',
#  '"스마트시티 성공 시민참여에 달려있어"',
#  '디블락, 대표이사에 오현석 파트너 선임',
#  '블록체인협회 "금융위 가상통화 가이드라인 환영"',
#  'HPE "엣지, 클라우드, 데이터기반으로 승부"',
#  '모바일 MMORPG ‘뮤 오리진’ 리버스 시스템 업데이트',
#  '한화생명 롤챔스 3위 도약…MVP는 성환·린다랑',
#  '쿠키런:오븐브레이크, ‘부엉이의 마법공방’과 ‘자몽맛 쿠키’ 공개',
#  '한국전자인증, 나이스데이터와 스마트컨트랙트 협약',
#  '‘천년지애M’ 국내 정식 출시…인게임 오픈 이벤트 등 진행',
#  '바르셀로나 이어 상하이까지 직접 찾은 권영수 “5G 구현할 서비스 고민 중”',
#  'Samsung Brings Enhanced Color Accuracy and Sharpness to Mobile Photos with New ISOCELL Plus Technolo …',
#  'KDDI and Samsung Successfully Complete Live Real-Time Free-Viewpoint Video Stream Test on 5G',
#  '웹젠, ‘일하기 좋은 회사’로 바뀐다',
#  '쏘카, 공유차량 1만대 돌파… ‘7만5000대 차량 감축 효과’',
#  '권영수 LGU+ “5G장비, 화웨이 가장 앞서…5G 킬러서비스는 고민”',
#  "[MWC 상하이] 中 대륙 강타한 '5G 코리아'",
#  "[MWC 상하이] 권영수 부회장, 5G 화웨이 장비 '도입'…삼성보다 빨라",
#  '권영수 LG유플러스 부회장 "5G 장비서 中 화웨이 가장 앞서"',
#  "LG유플러스, 화웨이 5G 장비 '호평'…도입 유력",
#  '\'화웨이\' 만난 권영수 LGU+ 부회장 "기술력 가장 앞선다"',
#  '권영수 LG유플러스 부회장, "이변 없는 한 화웨이 도입"...5G 서비스 구현 고민',
#  '[MWC상하이] 권영수 LGU+ 부회장 “화웨이만 봤다” 5G망 도입 초읽기',
#  '[MWC상하이] 에릭슨 찾은 황창규 KT 회장 “5G서 함께 좋은 성공 이루자”',
#  '웹젠, 자율출근제 시행..7월부터 오전 9~11시 자율 출근',
#  '메디포스트, 유럽 6개국서 간엽줄기세포 배양 방법 특허 획득',
#  '[전문]한경바이오헬스포럼 제5차 조찬간담회 토론 내용',
#  '‘메이플스토리 15주년’ 넥슨컴퓨터박물관, 야외 바람 숲에 아트벌룬 전시',
#  '이통3사, ‘동반성장 평가’서 최우수 등급…“중소협력사와 지속 상생해 나갈 것”',
#  '[부고] 박준성(에스원 경영지원실장)씨 모친상',
#  '뱅드림 걸즈 밴드 파티, ‘여자친구’의 히트곡 ‘밤’ 추가',
#  '[인사]한전KDN',
#  'LGU+, 5G 화웨이 장비 도입 유력해졌다',
#  '브랜든 김 삼성넥스트 투자총괄 “탈중앙화 시대, 제2의 우버·페이스북 나올 것”',
#  "카카오M '이병헌·김태리' 소속사 지분 사들인 까닭은?",
#  '[이슈] 영원한 7일의 도시, 출시 앞서 사전 다운로드 돌입',
#  "웹젠 ‘뮤 오리진’, 신대륙 '리버스' 업데이트",
#  '[부고]박준성씨(에스원 경영지원실장) 모친상',
#  '카카오M, 막강한 한류스타 군단 형성 … 영상 산업 영향력 강화',
#  '아프리카 가는 카이스트 ICT봉사단',
#  '"핀테크업체도 국제 수준 자금세탁방지 규제 따라야"',
#  '카카오M, 배우 매니지먼트사 2곳과 지분 인수 계약',
#  "구글 '애드워즈'·'더블클릭' 역사속으로",
#  '카오스재단, 최고 석학 초청 물리콘서트 개최',
#  '신작 모바일 RPG ‘신무월’ 사전예약 30만 “내달 출시”',
#  '권영수 LGU+ 부회장 “5G 장비, 화웨이가 가장 앞서”',
#  '"기간·비용 줄이는 AI 신약개발… 의료 빅데이터 개방이 관건"',
#  '‘삼국블레이드’, 신규 초월 ‘안량·문추’ 업데이트',
#  'SK그룹, 2018 확대경영회의 "사회적가치로 혁신하라"',
#  '트위터, 신규 계정 등록시 이메일·전화번호 확인한다',
#  "신약 후보물질 발굴부터 임상까지… 정부 주도 'AI 프로젝트' 추진한다",
#  '페이스북, 아퀼라 무인기 개발 중단',
#  '"국민 97%가 건보 적용… 양질 의료 데이터로 바이오 경쟁력 키울 것"',
#  '과기정통부, IPTV ·케이블·위성방송 시범평가 시행',
#  "한콘진, 일산에 '뉴콘텐츠센터' 개관",
#  '아이코보, 다이코 탑재한 모바일 지갑 공개',
#  '‘오버워치’, 이용 환경 개선책 ‘추천·그룹 찾기’ 기능 도입',
#  '모바일 MMORPG ‘열혈강호’, 한중 e스포츠 대회 내달 개최',
#  '넥슨컴퓨터박물관, 메이플스토리 캐릭터 아트벌룬 전시',
#  '2018 대한민국과학기술연차대회',
#  'KAIST ICT 봉사단, 에티오피아서 교육봉사',
#  '4차 산업혁명 이끌 콘텐츠 제작사 키운다',
#  'KTㆍLG 앞에서…5G 야심 드러낸 中 화웨이',
#  '“알뜰폰 구하기”… 올해도 전파사용료 면제 유력',
#  '[MWC 상하이 2018] 드론·VR게임… ‘5G의 미래’ 엿본다',
#  'SKT·KT, 최우수 이통사·5G 선도자 수상',
#  '공공데이터 창업의 산실 ‘오픈스퀘어-D 강원’ 오픈',
#  '동반위 "상생협약으로 중기적합업종 보호"',
#  '[알아봅시다] 보이지 않는 위협 전자파 막는 차폐 소재',
#  '황창규 - 권영수, 5G 상용화 `리더십 행보`',
#  '[YBM 톡톡 생활영어] You have what it takes! 넌 그 일을 해낼 자질이 있는 걸!',
#  '대기업 181곳중 15곳 낙제… 정보통신업종 대체로 `우수`',
#  '카카오M, 엔터사와 손잡고 "K콘텐츠 1위 사업자 도약"',
#  'LGU+, 한화토탈과 스마트 플랜트 MOU… LTE 고객전용망 기반 IoT 솔루션 개발',
#  '카카오 대리운전, 1000원 단위 현금결제 가능',
#  '종편·보도PP, 방발기금 징수율 상향',
#  '"특허비용 4G보다 낮출 것"… 가성비 승부수',
#  "예능과 만난 게임…홍보 효과 '톡톡'",
#  '우체국 등기우편 약 6년만 인상...170원 오른다',
#  '삼성이냐 화웨이냐… 5G 장비 도입 앞두고 고민 깊은 이통3사',
#  '인공지능 사업에 야심 드러낸 아마존, MS 인재 대거 스카웃',
#  '“美 SBIR처럼 연속성 있는 바이오 투자 정책 필요”',
#  "[2018 상반기 인기상품]품질우수-삼성전자 TV 'QLED TV'",
#  '?[2018 상반기 인기상품] 코드마인드, 프로그램 보안약점 등 정적분석 솔루션 제공',
#  "삼성디스플레이 '와이옥타' 패널 中 오포에 첫 판매",
#  "[2018 상반기 인기상품]품질우수-삼성전자 공기청정기 '삼성 큐브'",
#  '[2018 상반기 인기상품]품질우수-한위드정보기술 가상화솔루션',
#  "[2018년 상반기 인기상품]브랜드 우수-LDS테크, SSD서버 '2U서버'",
#  '[2018 상반기 인기상품]품질우수',
#  '[2018 상반기 인기상품]품질우수/브랜드우수',
#  "[2018 상반기 인기상품]브랜드우수-우경정보기술 '시큐워처 for CCTV'",
#  "[2018 상반기 인기상품]브랜드우수-지란지교에스앤씨 'MISO'",
#  "[2018 상반기 인기상품]품질우수-LG전자 에어콘 '휘센 씽큐'",
#  '[2018 상반기 인기상품]브랜드 우수-트렌드마이크로 `딥 시큐리티`',
#  '[2018 상반기 인기상품]브랜드우수 - 투씨에스지 데이터보호플랫폼',
#  "휴대폰 명의도용 피해 '뚝'···부정가입방지시스템 빛봤다",
#  '[2018 상반기 인기상품]품질우수-LG 디오스 얼음정수기 냉장고',
#  '[단독]"국산맥주 역차별 해소되나"...주류세 개편 첫 발',
#  '[2018 상반기 인기상품]고객만족/마케팅 우수 품목-LG 트롬 스타일러',
#  '[2018 상반기 인기상품]품질우수-옴니엘피에스, 옴니 쌍극자 피뢰침',
#  '[카드뉴스] 오늘의 게임소식 총정리 -6월 27일-',
#  '인터넷자율정책기구가 조현아·최태원 연관검색어 삭제 다르게 본 이유는?',
#  '대우전자-대유위니아, 제습기 시장 공략 본격화',
#  '원조 모바일 RPG명가 자존심 회복?..블레이드2 출시',
#  "가족기업 '머크'는 어떻게 350년을 계속했나",
#  '반도체 왕좌 앉은 삼성전자, 인텔과 격차 더 벌려',
#  '[제9회 퓨처ICT포럼] "IoT기기 제조 단계부터 적용할 보안 가이드라인 필요"',
#  '[제9회 퓨처ICT포럼] "IoT 단말기 고유기능만 가능한 \'머드폴리시\' 적용해야"',
#  '[인사]중소기업진흥공단',
#  '카카오M, 이병헌·공유 품고 해외로…BH엔터·숲엔터 등 지분 투자',
#  '한컴MDS, AI 기반 전시 안내 로봇 만든다',
#  '로봇카트·AI체험·5G통신…"4차산업혁명 온몸으로 느꼈다"',
#  '"AI 실생활에 빠르게 적용"…"데이터 확보없인 발전 한계"',
#  'AI면접관 "표정이 굳었군요"…가상면접 체험 구직자 `깜짝`',
#  '"규제장벽·인재난 절감한 1년"… 카카오브레인 CSO의 \'눈물\'',
#  '220兆 시장 선점 나선 中… 내년 5G 스마트폰 첫 출시',
#  '[2018 과학기술연차대회] 4차산업혁명 핵심 자율주행차 기술, 어느 수준?',
#  '\'현미경의 난시\' 고쳤다… "모든 광학·전파 장비 설계 바뀔 것"',
#  "'넘사벽' 카카오톡, 국내 모바일 메신저 점유율 94.4%",
#  '카카오M, 이병헌 소속사와 손 잡았다',
#  '의혹과 배신으로 얼룩진 ‘e불편한세상’',
#  "가민, 골퍼 위한 레이저 거리측정기 '어프로치Z80' 출시",
#  '[모바일한경] 멸종위기 눈표범을 살릴 수 있는 보드카 등',
#  '[단독] 美 "韓, 中과 5G·드론 기술협력 말라"',
#  '[제9회 퓨처ICT포럼] "5G, 20년간 10만개 마이크로산업 창출할 것"',
#  "[막오른 MWC] 6년간 85조 투자···시범도시 선정···중국 '5G 표준화' 주도권 잡아",
#  '[막오른 MWC] 5G 기술로 수술로봇·원격운전까지···황창규 "中 기술발전 예상 뛰어넘어"',
#  '[제9회 퓨처ICT포럼] "자율주행차, 역사상 가장 파괴적인 혁신"',
#  'KT, 해지한 휴대폰 번호 29일간 사용 금지',
#  '[제9회 퓨처ICT포럼] "4차산업혁명 꽃 피우려면 히든챔피언 기업이 선두에 서야"',
#  "[MWC 상하이]삼성 없이…화웨이·에릭슨·노키아 5G '각축'",
#  'KT, 다음달 2일부터 휴대폰 번호 재사용 ‘전면금지’',
#  "IT '주52시간' 급한 불 껐지만..'업무환경 열악' 선입견 우려도",
#  '화웨이 "내년 9월 5G폰 출시"…5G 장비 이어 단말기도 \'눈독\'(종합)',
#  '“해외서 한 ICO, 국내 자본시장법 적용 받을 수도”',
#  '[제9회 퓨처ICT포럼] 임현수 LG CNS 사원 "5G 기술로 스마트팩토리 실현, 힌트 얻었다"',
#  '[제9회 퓨처ICT포럼] "5G 시대, 상상 초월한 비즈니스 모델 쏟아져 나올 것"',
#  '피앤피시큐어 "15년간 성장..일본 이어 유럽도 진출"',
#  '[제9회 퓨처ICT포럼] "전세계 통신사, 5G 선뜻 못나선채 한국만 쳐다봐"',
#  '한컴지엠디, 드론 조종 자격증 교육용 VR시뮬레이터 개발',
#  '안랩, 금융권 대상 보안 전략 세미나 ‘ISF 스퀘어 2018’ 개최',
#  '한국후지쯔, 미래자판기연구소와 전략적 파트너십 체결',
#  '이통 3사, `동반성장지수 평가` 모두 `최우수`',
#  '웹젠, 자율근무제 도입..포괄임금제 전면 폐지',
#  "[원전 밸류체인이 무너진다] R&D도 '해체'에 집중..성능 향상엔 뒷전",
#  '"암호화폐 일정요건 갖춘 자율규제 바람직"',
#  '전자 영주권 도입...유럽 진출 꿈꾸는 글로벌 벤처 몰려',
#  '메디톡스, 지방분해 신약 개발 착수..."사업영역 확장"',
#  '[SMSC]"디지털 콘텐츠 성공 코드, B급이 지배"',
#  '[\'디지털 최강국\' 에스토니아 가보니]블록체인·빅데이터가 국가운영 OS..."e-ID 하나로 多돼요"',
#  '카카오M, 이병헌·공유·김태리 소속 연예기획사 투자',
#  "피파온라인4로 만든, 러시아 월드컵 2라운드 '베스트11'",
#  '광주 첨단 3지구에 AI 창업단지 조성한다…연구용역 추진',
#  "'스탯'으로 달라지는 카이저의 직업특성, 마법사 육성 방향은?",
#  "라이엇게임즈, 한국 문화 담은 '롤드컵 우승 스킨' 공개",
#  '유료방송 시장점유율 합산규제 일몰…시장 지각변동?',
#  '[핫클립]블랙핑크 뮤비에 감탄하는 외국인',
#  "카카오M, 이병헌·김태리 소속사 '지분투자', 협업체계 구축",
#  '폴 크루그먼 "한국 경제도 보복무역 전쟁에 노출"',
#  "'2018 대한민국과학기술연차대회 심포지엄'",
#  "'2018 대한민국과학기술연차대회 심포지엄'",
#  '스타벅스 과일 특성 그대로 담은 여름 음료 5종 출시',
#  '네이버 "광고비 최대 10만원까지 지원해드립니다"',
#  '페이스북, 암호화폐 광고 빗장 완화',
#  '[블록포스트] 디지털 아이디로 간편하게 입국..여권·비행기표가 필요없다',
#  '블록체인 창업의 요람 ‘해시드 라운지’ 오픈',
#  '삼성전자, 올 1분기 인텔과 격차 벌리며 세계 반도체 시장 1위 수성',
#  '대구창조경제혁신센터, "해외진출 원하는 스타트업, 대구로 오세요"',
#  "KT, 와이브로 철수 '급속 페달'",
#  "게임업계 '선택적 근로시간제' 확산…넷마블 넥슨 엔씨소프트 선도",
#  '한의학연구원 직원, 규정 어기고 진료행위하다 적발',
#  '[국제]“LG V40, 퀸터플 카메라 품는다”',
#  '이찬형 한국MSC소프트웨어 대표 "4차 혁명시대, 자율주행과 3D프린팅 시뮬레이션 시장 성장할 것"',
#  "[미래기업 포커스]유민에스티, 재사용 가능한 '화학용액 누설감지 센서' 개발",
#  '파워테크닉스, SiC 전력반도체 개발 명맥 잇는다',
#  "LG그룹, 4세대 경영 '구광모 대표이사' 체제 가동",
#  "[2018 상반기 인기상품]품질우수-LG전자 세탁기 '트롬 트윈워시'",
#  "[사설]원전 경쟁력 보여 준 '원자력 엑스포'",
#  '인스타그램으로 영상통화도 한다',
#  'LGU+, IoT활용 ‘스마트 플랜트’ 개발…한화토탈과 업무협약 체결',
#  "'오버워치', 추천 및 그룹 찾기 도입",
#  "'페이트/그랜드 오더', 레이드 퀘스트 라쇼몽 실시",
#  '웹젠, 자율출근제 시행 및 포괄임금제 폐지',
#  '"블록체인 열기는 거품" 애플 공동 창업자도 경고',
#  "'열혈강호 for kakao', 아시아 챔피언십 2018 7월 29일 개최",
#  '세계 종말 그린 슈팅 RPG ‘뉴본’, “손맛은 기본…스토리 일치성 높였다”',
#  '‘페이트 그랜드오더’ 첫 레이드 이벤트 ‘라쇼몽’ 실시',
#  '모바일 리듬게임 ‘뱅드림’, 여자친구 히트곡 ‘밤’ 추가',
#  '‘영원한 7일의 도시’ 28일 출시…사전 다운로드 시작',
#  '2018 인사이드 3D프린팅 컨퍼런스&엑스포 개막',
#  '오라클, 자바SE 월 구독 상품 출시...칩당 25달러',
#  '과기정통부, 일자리창출 지원에 700억 원 특구펀드 조성',
#  '한국지역정보개발원, 정보화마을 교육봉사자 양성교육 실시',
#  '강제참석 같지만 회식 근로시간 X, 체육대회 O···기준은',
#  "SKT·KT 5G 기술 국제 무대에서 호평, LGU+ '내실 다지기' 주력",
#  '산림청, 국민과 친근한 ‘수목장림’…2022년까지 50곳 조성',
#  '중기부, 국내 중소기업 `중국 동북3성` 진출 토대 다져',
#  '‘글로벌 바이오 콘퍼런스’ 개막...32개국서 3000명 참석',
#  '보령바이오, 임신성 질환 유전적 위험 예측 서비스 출시',
#  '대웅제약, 바이오시밀러 ‘삼페넷’ 심포지엄 개최...임상정보 공유',
#  '웹젠, 포괄임금제 폐지...7월1일부터 주 52시간 근무',
#  '카카오M, 이병헌·공유·김태리 등 한류 연예기획사 품 안으로… 종합 콘텐츠 기업 도약',
#  'KT, 7월 2일부터 변경·해지한 이동전화 번호 재사용 금지',
#  '카카오M, 이병헌·공유·김태리 한류 스타군 확보',
#  '디블락, 오현석 파트너 대표이사로 전격 선임',
#  'ETRI, 부산서 유망기술 설명회',
#  '애플, 아이폰6S로 인도 공략 가속… 현지만 출시할 듯',
#  '레진코믹스 5주년 기념 ‘135만 코인 쏜다’',
#  "HPE·삼성전자, CPU 의존도 낮춘 100배 빠른 '메모리 중심 컴퓨팅' 2년내 상용화",
#  "이노그리드, 오픈 클라우드 플랫폼인 '파스-타(PaaS-TA)와 연동",
#  '"규제 샌드박스 신기술·신사업부터 적용"',
#  "유료방송 무법천지?..KT 합산규제' 일몰됐지만 법 개정 움직임",
#  '웹젠, 7월부터 자율출근제 운영...포괄임금제 전면 폐지',
#  '졸음이 오는 이유, 드디어 밝혀졌다',
#  '"생산성 높였더니 ‘워라밸’이 따라왔다"',
#  '오픈소스컨설팅, ‘오픈 인프라 데이(OpenInfra Days) 코리아 2018’ 참가',
#  "넷마블 '페이트/그랜드 오더', 레이드 이벤트 ‘라쇼몽’ 실시",
#  '국내외 암호화폐 거래소 오가는 외화 모니터링 강화',
#  '이통3사, 동반성장지수 평가에서 ‘최우수 명예기업’',
#  '넥슨컴퓨터박물관, ‘메이플스토리’ 아트벌룬 프로젝트 진행',
#  '日탐사선 하야부사2, 3년반 만에 목표지점 도착…32억㎞ 여행',
#  '여름에는 PC도 힘들다, 무더위 극복하려면?',
#  '농진청 연구원 4명, 과학기술우수논문상 수상',
#  '외계 생명체 탐사 탄력…2년 연구 끝에 전략·방향 제시',
#  '[MWC상하이] 화웨이, 5G 특허비용 대폭 낮춘다',
#  '상반기 특허기술 대상에 `방사성 세슘 제거기술`',
#  '"우주정책, 산업키워 국가 성장동력화해야"',
#  '네이버, 동반성장지수 평가 2년 연속 ‘최우수’ 등급 획득',
#  'LG, 다문화 청소년 이중언어 인재로 육성',
#  '[리뷰] 알뜰파 디자이너를 위한 모니터, 벤큐 PD2500Q',
#  "美대법원 '휴대폰 위치추적 영장필수' 맞나?",
#  '‘안마의자’ 계약·품질 등 소비자 불만 급증…무리하게 사용시 골절 유발',
#  '엔씨 ‘블레이드앤소울’,신규 스토리 ‘악천후 외전’ 추가',
#  '[2018 상반기 인기상품]품질우수-아드반테스트코리아 반도체테스트장비',
#  '카카오M, 이병헌 소속된 연예 기획사 등과 협업',
#  '돼지 각막 이식받은 원숭이, 1년 넘게 정상...인간 이종이식 임상 한발 더 가까와지다',
#  '4:33 ‘삼국블레이드’, 초월 장수 안량-문추 추가',
#  "황창규 KT 회장, 세계이동통신협회 '임원활동' 재개",
#  "바탕화면에 도넛이?...'도넛 랜섬웨어' 주의보",
#  "[이슈] 페이트/그랜드오더, 첫 레이드 이벤트 '라쇼몽' 실시",
#  '쿠키런: 오븐브레이크, 새 캐릭터 ‘자몽맛 쿠키’ 추가',
#  '7년 만에 공유차량 1만대 넘긴 쏘카',
#  '카카오M, 이병헌·김태리 소속사에 지분투자…IPO 추진',
#  '가민, GPS 결합 레이저 거리측정기 ‘어프로치 Z80’ 출시',
#  "이통3사, 동반성장지수평가 '최우수' 등급",
#  "네이버, 동반성장지수 평가 2년 연속 '최우수' 등급 획득",
#  "[이슈] 뱅드림 걸즈 밴드 파티, 여자친구 히트곡 '밤' 제공",
#  'TTA, 스마트공장·사물인터넷 단체표준 채택',
#  'SKT·KT·LGU+, 동반성장지수 ‘최우수’',
#  'LG, 다문화가정 청소년 교육 지원',
#  '네이버 “검색광고 체험해보세요”…최대 10만원 광고비 지원',
#  'LG디스플레이, 4년 연속 동반성장지수 최우수 기업 선정',
#  '삼성·LGD, 대형 OLED 사업 전환 박차',
#  '카카오M, 연예기획사 3곳에 투자...M&A도?',
#  '빗썸 해킹 원인 됐나…"외주 직원PC 침해"',
#  '피싱 메일에는 실제로 어떤 내용이 담겨있을까?',
#  '화웨이 CEO "장비가격 낮춰 5G 진입문턱 낮추겠다"',
#  '캐디 없이 골프 친다…가민, GPS 거리 측정기 국내 출시',
#  '카카오M, “K-컬쳐 앞세워 세계 공략할 것”',
#  '영원한 7일의 도시, 28일 모바일 양대 마켓 정식 출시',
#  "넥슨컴퓨터박물관, '메이플스토리' 캐릭터 아트벌룬 전시",
#  "모바일 무협MMORPG '천년지애M', 3대 앱마켓 출시",
#  '한국후지쯔, 미래자판기연구소와 전략적 파트너십',
#  "'퍼즐앤드래곤', '매직: 더 개더링'과 컬래버레이션 진행",
#  '2018 대한민국과학기술연차대회 주제 강연',
#  '2018 대한민국과학기술연차대회 심포지엄 주제 강연',
#  '주제 강연하는 임대식 과학기술혁신본부장',
#  '"전문가가 상담해드려요"…라인, 日에서 \'토크CARE\' 서비스',
#  '화웨이 "내년 9월 5G폰 출시"… 장비 이어 단말기도 \'눈독\'',
#  "닌텐도 스위치용 '빅터 브란 오버킬 에디션', 한국어판 8월 출시",
#  '지케이테코, 한국어 웹사이트 전면 개편',
#  "'삼국블레이드', 안량과 문추 초월 장수로 등장",
#  '우버, 런던서 퇴출 위기 넘겼다…15개월 영업 면허 갱신',
#  "HPE '지능형 엣지컴퓨팅'에 4조 투입…주력으로 키운다",
#  '[MWC상하이] 흔적도 없는 ZTE 부스, 미국 제재조치 때문?',
#  'LG유플러스-한화토탈, IoT 기술로 스마트 플랜트 만든다',
#  "야놀자·여기어때, 숙박 이어 '액티비티' 경쟁 펼친다",
#  "위시인터랙티브, 모바일게임 '운명의사랑: 궁' 사전예약 시작",
#  "KT, '텔레콤 아시아 어워드' 수상으로 5G 기술력 입증",
#  '벽람항로 헝앱, 빵터지는 대사를 찾아라 미션 진행',
#  "애드박스, 모바일 게임 '로드 오브 히어로' 캠페인 추가",
#  '모비톡, 갤럭시S8 및 아이폰7 한정 수량 특가 이벤트 시작',
#  '[주목! 이 사람]카츠노리 콘도 아소비모 CEO "리버스 ICO, 수수료 없는 콘텐츠 플랫폼 구축 첫걸음"',
#  "LG유플러스, 4년 연속 동반성장지수 평가 '최우수'",
#  "전주시 주도 '드론축구' 국제행사에 첫선…드론축구 세계화 시동",
#  '황창규 KT 회장, "5G는 국가경쟁…중국 큰 진전" 평가',
#  "'세븐나이츠', 펫 7종 각성 시스템 추가",
#  '중저가 외산폰의 역습, 통할까',
#  "발전소·공항 등 표적 '망 분리 무력화' 사이버 공격 발견",
#  '삼성바이오로직스, 일본 바이오·제약 전시회 참가···CDO 고객 발굴',
#  'SKB, 인터넷 신규 가입 이벤트 실시',
#  'MWC 상하이 개막…황창규 KT 회장 "5G는 국가간 경쟁"',
#  '웹젠, 7월부터 자율출근제 시행…포괄임금제 폐지',
#  "뱅드림! 걸즈 밴드 파티, 여자친구 '밤' 연주곡 업데이트",
#  '화웨이 "내년 9월 5G폰 출시"…5G 장비 이어 단말기도 \'눈독\'',
#  "일본 연구팀, '졸음의 정체' 마침내 규명",
#  '[부고]정인선(안양상공회의소 본부장)씨 장인상',
#  '화웨이 "5G특허료 낮출 것...내년 9월 5G폰 출시"',
#  '[인사]중소기업진흥공단',
#  '임대식 "과기혁신 원년...R&D 시스템 개선 등 변화 속도"',
#  '광주 첨단 3지구에 1조원대 인공지능 창업단지 조성 추진',
#  'KEA, 충남 공주시에서 휴대폰·가전제품 무상점검 순회 서비스',
#  '황창규 "5G, 국가경쟁 되고 있어…中기술 진전, 예상 뛰어넘어"',
#  '한국세라믹기술원장에 유광수 서울시립대 교수',
#  "삼성전자, 'QLED TV 매직스크린' 글로벌 디자인 공모전...우승상금 8000유로",
#  "전주 發 드론축구, 이젠 '해외로'…국제전시회서 선봬",
#  '탈원전 정책 영향?…KAIST 원자력학과 전공선택 5명 뿐',
#  "'리니지M' 정기점검 후 '앱 종료' '시련 던전 완료 후 팅김 현상' 등 오류 발생",
#  '국제특허 전자출원절차 간소화… 특허로·e-PCT 연동작업 착수',
#  "루프 RPG '영원한 7일의 도시' 28일 양대 마켓 출시",
#  '유료방송 품질평가 실시 공식 발표...정부 “품질 경쟁 환경 조성”',
#  '룽투, ‘열혈강호 포 카카오 아시아 챔피언십 2018’ 7월 개최',
#  '웹젠, 자율출근제 시행…포괄임금제 폐지',
#  "네이버 2017년 동반성장지수 평가 '최우수' 등급...2016년 이어 2년 연속",
#  '축사하는 유영민 장관',
#  '블리자드 ‘오버워치’, 추천 및 그룹 찾기 기능 추가',
#  '강연하는 임대식 과학기술혁신본부장',
#  '한국인 외국보다 고기 덜 먹는다...식약처 섭취 실태 조사',
#  "'포스트 리니지' 찾는 엔씨…신작 라인업에 2종 추가",
#  '동반성장위, 2017년 동반성장지수 평가 결과 발표',
#  "임대식 과학기술혁신본부장 '사람중심 과학기술혁신정책'",
#  '대한민국과학기술연차대회 심포지엄',
#  "'2018 대한민국과학기술 연차대회 개회식'",
#  "'2018 대한민국과학기술 연차대회 개회식'",
#  '[2018 과학기술연차대회] 임대식 과기본부장, "경제 아닌 사람중심 R.D 혁신으로 간다"',
#  "달아오르는 월드컵 열기…'피파온라인4'서도 후끈",
#  '[기획]먹는 물 위생 끝판왕, LG 퓨리케어 슬림 정수기',
#  '"\'캠페인\'에만 빠진 기업 문화, 총체적 변화 필요"',
#  "[기획]더 깨끗하고, 더 건강한 물 연구…LG전자 '물과학연구소'",
#  '웹젠, 자율출근제 시행…포괄임금제도 전면 폐지',
#  "JW신약, 충치 예방 치아 트레이 '불소원카' 출시",
#  "[이슈] 꿀알바 어플 애드박스, 신작 모바일게임 '로드 오브 히어로' 캠페인 추가",
#  "[이슈] 벽람항로 헝그리앱, '빵터지는 대사를 찾아라' 이벤트 진행",
#  '[이슈] 갤럭시S8 0원·아이폰7 10만 원대…모비톡, 한정 수량 특가 이벤트 시작',
#  '[MWC 상하이]화웨이 CEO "5G 라이선스비 대폭 낮춘다"',
#  '[혁신기업을 가다]모바일어플라이언스, 자율주행차 시대 이끈다',
#  '인바디 혈압계, 유럽고혈압학회 임상시험 국내 최초 통과',
#  '[국제]EU 가구 25% 광가입자망 이용 중',
#  '700억 규모 특구펀드 조성… 공공기술사업화 기업 투자',
#  '광주북부소방서, 민원수수료 납부에 간편결제 도입',
#  '[종합]"바이오산업 규제 선진화"… 2018 글로벌 바이오 콘퍼런스 개막',
#  '기업은행, 中企 재직자 교통비 지원 카드 출시',
#  '더맘마, 씨엔티테크에서 8만불 투자유치',
#  '중고폰 거래 어플 모비톡, ‘안전한 중고거래 방법 3가지’ 알려',
#  '애드박스, 신작 모바일게임 ‘로드 오브 히어로’ 캠페인 추가',
#  "탈원전 정책에…카이스트 원자력 학과 전공 선택 '0'",
#  '옥션 "장마철 대비 제습용품 수요 급증"',
#  '종편·보도채널 방발기금 징수율 1.5%로 인상',
#  'GS샵, 6월 남성의류 취급액 전년 동월 比 159%↑',
#  '엠제이이엔엠, 무협소설 기반 신작 ‘십병귀’ 사전등록 실시',
#  '카카오뱅크, 26주 적금 출시',
#  '[인사]한국원자력의학원',
#  "[이슈] 웹젠, '자율출근제' 시행 및 '포괄임금제' 전면 폐지",
#  'CJ ENM 대표이사에 허민회 총괄부사장',
#  'HPE "지능형 엣지 컴퓨팅에 4년간 4조 투자할 것"',
#  '선데이토즈 ‘애니팡3’, 여름맞이 업데이트 실시',
#  '메카로, 지르코늄 전구체 제조 기술 특허기술상 수상',
#  "이통3사, 2017 동반성장지수 '최우수'",
#  'LGU+, 4년 연속 동반성장지수 최우수 등급 받았다',
#  '보안, 5G시대의 핵심 키워드',
#  '퓨처ICT포럼 패널토론 두번째',
#  '웹젠, 자율출근제 도입하고 포괄 임금제 폐지',
#  'HPE "AI·빅데이터 시대, \'메모리 내 처리 기술\'에 답있다"',
#  '네이버, 동반성장지수 평가 2년 연속 ‘최우수’ 등급',
#  '[이슈] 모비톡, 갤럭시S9 10만 원대·갤럭시A7 2017 0원 특별 할인',
#  'KT-문체부, ‘직장 문화배달’ 나섰다',
#  'SK브로드밴드 "홈페이지서 가입하고 누구미니 받으세요"',
#  'LG유플-한화토탈, IoT 활용 스마트 플랜트 만든다',
#  "네이버, 2년 연속 동반성장지수 '최우수' 받아",
#  'MWC 상하이 개막… 화웨이 장비 도입 촉각',
#  'MWC 상하이 개막… 화웨이 장비 도입 촉각',
#  'MWC 상하이 개막… 화웨이 장비 도입 촉각',
#  'MWC 상하이 개막… 화웨이 장비 도입 촉각',
#  "'대한민국과학기술연차대회 축사하는 유영민 장관",
#  '현대약품, 당뇨병 치료제 후보물질 안정적 혈당조절 능력 갖춰',
#  "아프리카TV, 스타크래프트 아마추어 리그 'ACS' 개최",
#  "글로벌 빅이벤트 덕에 스포츠게임 '흥행몰이'",
#  "[이슈] 열혈강호 for kakao, 韓中 자존심 건 '아시아 챔피언십 2018' 개최",
#  "잠자리 날개처럼 투명하고 거미줄처럼 강한 '나노종이' 개발",
#  '[와우! 과학] 지구상에서 가장 추운 지역의 최저 온도는?',
#  "가민 '어프로치 Z80' 국내 출시… “GPS·레이저 결합해 골프 거리 측정”",
#  'CDO 고객발굴 나선 삼성바이오로직스',
#  '네이버뉴스 어떻게 달라지나 보니…',
#  "'대한민국과학기술연차대회' 대한민국최고과학기술인상 시상",
#  '피앤피시큐어, 올해 300억원 목표..내년 코스닥 간다',
#  '박수치는 유영민 과기정통부 장관',
#  '축사하는 유영민 과기정통부 장관',
#  '박수치는 유영민 과기정통부 장관',
#  '유영민 장관, 2018 대한민국과학기술연차대회 시장',
#  '아프리카TV, 오락실 게임 대회 ‘고인물 게임대전 시즌2’ 내달 개최',
#  '<사진>2018 대한민국과학기술연차대회 개최',
#  'HPE, 님블스토리지-심플리비티 신제품 출시..."스토리지 시장 점유율 끌어올리겠다"',
#  "삼성전자, 이미지센서 신기술 '아이소셀 플러스' 발표",
#  "아프리카TV, 오락실 게임 종목으로 진행하는 '고인물 게임대전' 시즌2 개최",
#  '종편·보도채널 방송통신발전기금 징수율 1.5%로 인상(종합)',
#  'KAIST-대만 교육부, 글로벌 인재 양성 협약 체결',
#  '와이제이엠게임즈, VR카페 ‘엔터 VR’ 부천점 오픈',
#  '스타트업, ‘컬러’에 주목하다',
#  '슈프리마아이디, 프랑스 정부 차세대 전자여권 발급 사업 선정',
#  '기업 성장하려면, 무심한 듯 충성하는 고양이 전략 따르라',
#  "KT, 29일 '삼성전자 갤럭시진' 단독 출시",
#  "[포토]이데일리에서 열린 '2018 국민대학교 Future Korea 심포지움'",
#  "[포토]이데일리에서 열린 '2018 Future Korea 심포지움'",
#  "[포토]국민대학교, '2018 Future Korea 심포지움' 개최",
#  "[포토]국민대학교, '2018 Future Korea 심포지움' 열어",
#  "[포토]국민대, '2018 Future Korea 심포지움' 열어",
#  "[포토]국민대, '2018 Future Korea 심포지움' 개최",
#  "[포토]'한국형 4차 산업혁명의 모색-현안과 추진전략'이란",
#  "[포토]'한국형 4차 산업혁명의 모색-현안과 추진전략'이란 주제로 열린 'Future Korea ...",
#  "수산아이앤티, 'eReD' 로 가상화폐거래소 해킹 막는다",
#  "[포토]'국민대학교 Future Korea 심포지움'",
#  "[포토]'2018 국민대학교 Future Korea 심포지움'",
#  '‘열혈강호 아시아 챔피언십 2018’ 7월 29일 서울 개최',
#  '700억원 규모 특구펀드로 일자리 늘린다',
#  '위시인터랙티브, 3D 모바일게임 ‘운명의사랑: 궁 ’ 사전예약 실시',
#  "경기도경제과학진흥원, 내달 21~22일 'ICT 스마트 디바이스톤' 개최",
#  "KGC인삼공사 지니펫, 국내최초 '반려견 대상 면역력 입증' 기념 행사",
#  '레진코믹스, 서비스 5주년 기념 이벤트 진행',
#  '"5G 미리보자" 인산인해…카트로 사람 실어나르는 상하이',
#  "대통령 주재 제2차 규제혁신 점검회의 '연기'..총리, 내용보강 필요 건의",
#  '남극 해양미생물 활용 혈액 동결보존제 세계 첫 개발',
#  "KT-문체부, '직장 문화배달' 나서",
#  '방통위, 신고·인가관련 방송법 등 일부개정안 의결',
#  '블록체인 액셀러레이터 ‘해시드’, 코워킹 스페이스 오픈',
#  "HPE, 엣지컴퓨팅 '승부수'…4년간 4조 투입",
#  "'새로운경기위원회' 이틀만에 정책 제안 1700건 돌파",
#  '삼성전자 ‘QLED TV 매직스크린’ 글로벌 디자인 공모전',
#  '네이버, 검색광고 체험 프로그램 진행',
#  '중앙재난방송협의회, 재난방송 효율화·책임성 강화 논의',
#  '능력은 충분, 세계 점유율은 0.1%? "우주기술, 정부→민간 무게추 이동해야"',
#  '"우주개발 정부 중심 탈피해야"…\'우주혁신 성장 토론회\'',
#  "중앙재난방송협의회 '유료방송도 재난방송 실적평가' 첫 논의",
#  '정보통신기술사협회, 정보시스템 감리 심포지엄 개최',
#  '에스에스알 "코스닥 예비심사 승인...8월초 상장"',
#  'GC녹십자랩셀, 캐나다 팰던 테라퓨틱스 ‘플랫폼 기술’ 도입',
#  '황창규 KT 회장, "5G는 기업경쟁 아닌 국가경쟁…중국 큰 진전" 평가',
#  '황창규 KT 회장, "5G는 기업경쟁 아닌 국가경쟁…중국 큰 진전" 평가',
#  '블록체인으로 쓰는 출판문화의 새로운 가능성',
#  'MWC 상하이 찾은 황창규 KT 회장',
#  '4차산업의 주력아이템 개발·진행, 국내 핀테크 기술 분야 선도',
#  "‘SAS 바이야(SAS Viya)' 등 빅데이터 분석 플랫폼 각광",
#  '황창규 KT 회장 "5G는 4차 산업혁명과 연결된 국가간 경쟁”',
#  'KAIST 학생 51명, 아프리카 찾아 ICT 교육 봉사활동 펼친다',
#  'ETRI, 부산에서 사업화유망기술 설명회…우수 보유기술 이전',
#  '동서식품장학회, 장학증서 수여식 개최…5400만원 장학금 전달',
#  '“우리 동네 출산지원책 한눈에 살펴보세요”',
#  '종편·보도채널 올해 방발기금 오른다…1%→1.5%',
#  'GS25, 업계 유일 2년 연속 동반성장지수 우수 등급',
#  '보스코인 대표 "기술-비즈니스 연계, 올해 보여줄 것"',
#  "정용진표 펀스토어 '삐에로쑈핑' 공개...쇼핑 신세계 열다",
#  'CJ제일제당, 식품업계 최초 동반성장 최우수 명예기업 등극',
#  '남방큰돌고래는 빙하기가 괴로워',
#  '퓨처ICT포럼 패널토론',
#  '네이버, 검색광고 첫거래 소상공인에 10만원 지원',
#  '제9회 퓨처ICT포럼 패널토론',
#  '방통위, 신고·인가 관련 법 개정…"합리적으로 정비"',
#  '신도리코, 산업용 3D프린터 라인업 대거 확대...연 1만대 제품 판매한다',
#  '프로메테우스, 글로벌 기업 스트라타시스와 맞손',
#  "KT&G '릴'과 '핏', 판매처 전국 확대",
#  'KAIST, 아프리카 ICT 봉사단 발대식',
#  "[이슈] 넥슨컴퓨터박물관, '메이플스토리' 아트벌룬 전시",
#  '방통위, 종편·보도채널 방송통신발전기금 1.5%로 인상',
#  '엡손, 사이니지 전용 레이저 프로젝터 국내 출시...프로젝터 활용 다양화한다',
#  "방통위 '방송서비스 중단시 수리필요' 법안 의결",
#  '대우전자-대유위니아, 제습기 시장 공략 본격화',
#  '축사하는 송희경 자유한국당 국회의원',
#  '환담하는 유영민 장관과 전재호 회장',
#  '환담하는 토마스 프레이 미래학자와 전재호 회장',
#  '환영사하는 유영민 과학기술정보통신부 장관',
#  '기조강연하는 토마스 프레이 미래학자',
#  '기조연설하는 토마스 프레이',
#  '강연하는 토마스 프레이 미래학자',
#  '연설하는 토마스 프레이',
#  '[ICT 명품인재 양성사업]연세대, VR/AR 헤드셋 지원 핸즈프리인터페이스 장치 개발 성과',
#  '기조연설하는 토마스 프레이 미래학자',
#  '[ICT 명품인재 양성사업]한국뉴욕주립대 최봉준 교수, 잠재의식 고유패턴 이용 사용자 인증기술 개발',
#  '헬스케어 의료데이터 가명정보 이용을 허하라',
#  'LG디스플레이, 4년 연속 동반성장지수 ‘최우수 기업’',
#  "삼성전자, 이미지센서 신기술 '아이소셀 플러스' 공개",
#  "[이슈] 야망, '인기순위 급상승' 및 '무료 인기순위' 1위 올라",
#  '유료방송 합산규제법 다시 발의된다',
#  '최태원·조현아 연관 검색어 ‘삭제’…왜?',
#  '배틀그라운드 모바일, 매출 순위 다시 급상승',
#  'LGU+ "IoT기술로 스마트 플랜트 선도"',
#  "[이슈] 퍼즐앤드래곤, '매직 : 더 개더링과 컬래버레이션 진행",
#  '기념촬영하는 참석자들',
#  '네덜란드-캐나다, 블록체인으로 여권없는 여행 가능해진다',
#  "[이슈] 쿠키런: 오븐브레이크, '부엉이의 마법공방' 및 '자몽맛 쿠키' 업데이트",
#  '[인사]중앙선거관리위원회',
#  '[부고]이상헌(LIG넥스원 차장)씨 장인상',
#  '방통위, 신고제·인가제 관련 방송관계법률 일부개정안 의결',
#  '[블록체in 네덜란드③] 네덜란드에서 본 한국 블록체인의 가능성',
#  "'제9회 퓨처ICT포럼' 토마스 프레이 미래학자 기조연설",
#  "'제9회 퓨처ICT포럼' 기조연설",
#  '토마스 프레이 미래학자가 말하는 미래는?',
#  "'블레이드 & 소울', 악천후 외전 및 천명 부화장 던전 추가",
#  '뮤 오리진, 고레벨 유저 위한 어둠의 신대륙 리버스 추가',
#  "'로스트사가', 사관생도 코스튬 추가",
#  '야놀자·여기어때, 레저·액티비티 예약서비스 시작',
#  '한국후지쯔, 미래자판기연구소와 전략적 파트너십 체결']

# %%
def navertitle2(pageNum=10):
    driver = webdriver.Chrome()
    header = []
    for i in range(1,pageNum+1):
        url = 'http://news.naver.com/main/list.nhn?mode=LSD&mid=sec&sid1=105&date=20180627&page={}'.format(i)
        driver.get(url)
        titles1 = driver.find_elements_by_css_selector('.type06_headline li')
        titles2 = driver.find_elements_by_css_selector('.type06 li')
        for title1 in titles1:
            header.append(title1.find_element_by_css_selector('dt:not(.photo) > a').text)
        for title2 in titles2:
            header.append(title2.find_element_by_css_selector('dt:not(.photo) > a').text)
    driver.quit()
    return header

# %%
navertitle2()
# Out:
# ['[IT신상공개] 좋다는 것만 다 집어 넣은 느낌, 로지텍 G512 GX 블루 키보드',
#  '"스마트시티 성공 시민참여에 달려있어"',
#  '디블락, 대표이사에 오현석 파트너 선임',
#  '블록체인협회 "금융위 가상통화 가이드라인 환영"',
#  'HPE "엣지, 클라우드, 데이터기반으로 승부"',
#  '모바일 MMORPG ‘뮤 오리진’ 리버스 시스템 업데이트',
#  '한화생명 롤챔스 3위 도약…MVP는 성환·린다랑',
#  '쿠키런:오븐브레이크, ‘부엉이의 마법공방’과 ‘자몽맛 쿠키’ 공개',
#  '한국전자인증, 나이스데이터와 스마트컨트랙트 협약',
#  '‘천년지애M’ 국내 정식 출시…인게임 오픈 이벤트 등 진행',
#  '바르셀로나 이어 상하이까지 직접 찾은 권영수 “5G 구현할 서비스 고민 중”',
#  'Samsung Brings Enhanced Color Accuracy and Sharpness to Mobile Photos with New ISOCELL Plus Technolo …',
#  'KDDI and Samsung Successfully Complete Live Real-Time Free-Viewpoint Video Stream Test on 5G',
#  '웹젠, ‘일하기 좋은 회사’로 바뀐다',
#  '쏘카, 공유차량 1만대 돌파… ‘7만5000대 차량 감축 효과’',
#  '권영수 LGU+ “5G장비, 화웨이 가장 앞서…5G 킬러서비스는 고민”',
#  "[MWC 상하이] 中 대륙 강타한 '5G 코리아'",
#  "[MWC 상하이] 권영수 부회장, 5G 화웨이 장비 '도입'…삼성보다 빨라",
#  '권영수 LG유플러스 부회장 "5G 장비서 中 화웨이 가장 앞서"',
#  "LG유플러스, 화웨이 5G 장비 '호평'…도입 유력",
#  '\'화웨이\' 만난 권영수 LGU+ 부회장 "기술력 가장 앞선다"',
#  '권영수 LG유플러스 부회장, "이변 없는 한 화웨이 도입"...5G 서비스 구현 고민',
#  '[MWC상하이] 권영수 LGU+ 부회장 “화웨이만 봤다” 5G망 도입 초읽기',
#  '[MWC상하이] 에릭슨 찾은 황창규 KT 회장 “5G서 함께 좋은 성공 이루자”',
#  '웹젠, 자율출근제 시행..7월부터 오전 9~11시 자율 출근',
#  '메디포스트, 유럽 6개국서 간엽줄기세포 배양 방법 특허 획득',
#  '[전문]한경바이오헬스포럼 제5차 조찬간담회 토론 내용',
#  '‘메이플스토리 15주년’ 넥슨컴퓨터박물관, 야외 바람 숲에 아트벌룬 전시',
#  '이통3사, ‘동반성장 평가’서 최우수 등급…“중소협력사와 지속 상생해 나갈 것”',
#  '[부고] 박준성(에스원 경영지원실장)씨 모친상',
#  '뱅드림 걸즈 밴드 파티, ‘여자친구’의 히트곡 ‘밤’ 추가',
#  '[인사]한전KDN',
#  'LGU+, 5G 화웨이 장비 도입 유력해졌다',
#  '브랜든 김 삼성넥스트 투자총괄 “탈중앙화 시대, 제2의 우버·페이스북 나올 것”',
#  "카카오M '이병헌·김태리' 소속사 지분 사들인 까닭은?",
#  '[이슈] 영원한 7일의 도시, 출시 앞서 사전 다운로드 돌입',
#  "웹젠 ‘뮤 오리진’, 신대륙 '리버스' 업데이트",
#  '[부고]박준성씨(에스원 경영지원실장) 모친상',
#  '카카오M, 막강한 한류스타 군단 형성 … 영상 산업 영향력 강화',
#  '아프리카 가는 카이스트 ICT봉사단',
#  '"핀테크업체도 국제 수준 자금세탁방지 규제 따라야"',
#  '카카오M, 배우 매니지먼트사 2곳과 지분 인수 계약',
#  "구글 '애드워즈'·'더블클릭' 역사속으로",
#  '카오스재단, 최고 석학 초청 물리콘서트 개최',
#  '신작 모바일 RPG ‘신무월’ 사전예약 30만 “내달 출시”',
#  '권영수 LGU+ 부회장 “5G 장비, 화웨이가 가장 앞서”',
#  '"기간·비용 줄이는 AI 신약개발… 의료 빅데이터 개방이 관건"',
#  '‘삼국블레이드’, 신규 초월 ‘안량·문추’ 업데이트',
#  'SK그룹, 2018 확대경영회의 "사회적가치로 혁신하라"',
#  '트위터, 신규 계정 등록시 이메일·전화번호 확인한다',
#  "신약 후보물질 발굴부터 임상까지… 정부 주도 'AI 프로젝트' 추진한다",
#  '페이스북, 아퀼라 무인기 개발 중단',
#  '"국민 97%가 건보 적용… 양질 의료 데이터로 바이오 경쟁력 키울 것"',
#  '과기정통부, IPTV ·케이블·위성방송 시범평가 시행',
#  "한콘진, 일산에 '뉴콘텐츠센터' 개관",
#  '아이코보, 다이코 탑재한 모바일 지갑 공개',
#  '‘오버워치’, 이용 환경 개선책 ‘추천·그룹 찾기’ 기능 도입',
#  '모바일 MMORPG ‘열혈강호’, 한중 e스포츠 대회 내달 개최',
#  '넥슨컴퓨터박물관, 메이플스토리 캐릭터 아트벌룬 전시',
#  '2018 대한민국과학기술연차대회',
#  'KAIST ICT 봉사단, 에티오피아서 교육봉사',
#  '4차 산업혁명 이끌 콘텐츠 제작사 키운다',
#  'KTㆍLG 앞에서…5G 야심 드러낸 中 화웨이',
#  '“알뜰폰 구하기”… 올해도 전파사용료 면제 유력',
#  '[MWC 상하이 2018] 드론·VR게임… ‘5G의 미래’ 엿본다',
#  'SKT·KT, 최우수 이통사·5G 선도자 수상',
#  '공공데이터 창업의 산실 ‘오픈스퀘어-D 강원’ 오픈',
#  '동반위 "상생협약으로 중기적합업종 보호"',
#  '[알아봅시다] 보이지 않는 위협 전자파 막는 차폐 소재',
#  '황창규 - 권영수, 5G 상용화 `리더십 행보`',
#  '[YBM 톡톡 생활영어] You have what it takes! 넌 그 일을 해낼 자질이 있는 걸!',
#  '대기업 181곳중 15곳 낙제… 정보통신업종 대체로 `우수`',
#  '카카오M, 엔터사와 손잡고 "K콘텐츠 1위 사업자 도약"',
#  'LGU+, 한화토탈과 스마트 플랜트 MOU… LTE 고객전용망 기반 IoT 솔루션 개발',
#  '카카오 대리운전, 1000원 단위 현금결제 가능',
#  '종편·보도PP, 방발기금 징수율 상향',
#  '"특허비용 4G보다 낮출 것"… 가성비 승부수',
#  "예능과 만난 게임…홍보 효과 '톡톡'",
#  '우체국 등기우편 약 6년만 인상...170원 오른다',
#  '삼성이냐 화웨이냐… 5G 장비 도입 앞두고 고민 깊은 이통3사',
#  '인공지능 사업에 야심 드러낸 아마존, MS 인재 대거 스카웃',
#  '“美 SBIR처럼 연속성 있는 바이오 투자 정책 필요”',
#  "[2018 상반기 인기상품]품질우수-삼성전자 TV 'QLED TV'",
#  '?[2018 상반기 인기상품] 코드마인드, 프로그램 보안약점 등 정적분석 솔루션 제공',
#  "삼성디스플레이 '와이옥타' 패널 中 오포에 첫 판매",
#  "[2018 상반기 인기상품]품질우수-삼성전자 공기청정기 '삼성 큐브'",
#  '[2018 상반기 인기상품]품질우수-한위드정보기술 가상화솔루션',
#  "[2018년 상반기 인기상품]브랜드 우수-LDS테크, SSD서버 '2U서버'",
#  '[2018 상반기 인기상품]품질우수',
#  '[2018 상반기 인기상품]품질우수/브랜드우수',
#  "[2018 상반기 인기상품]브랜드우수-우경정보기술 '시큐워처 for CCTV'",
#  "[2018 상반기 인기상품]브랜드우수-지란지교에스앤씨 'MISO'",
#  "[2018 상반기 인기상품]품질우수-LG전자 에어콘 '휘센 씽큐'",
#  '[2018 상반기 인기상품]브랜드 우수-트렌드마이크로 `딥 시큐리티`',
#  '[2018 상반기 인기상품]브랜드우수 - 투씨에스지 데이터보호플랫폼',
#  "휴대폰 명의도용 피해 '뚝'···부정가입방지시스템 빛봤다",
#  '[2018 상반기 인기상품]품질우수-LG 디오스 얼음정수기 냉장고',
#  '[단독]"국산맥주 역차별 해소되나"...주류세 개편 첫 발',
#  '[2018 상반기 인기상품]고객만족/마케팅 우수 품목-LG 트롬 스타일러',
#  '[2018 상반기 인기상품]품질우수-옴니엘피에스, 옴니 쌍극자 피뢰침',
#  '[카드뉴스] 오늘의 게임소식 총정리 -6월 27일-',
#  '인터넷자율정책기구가 조현아·최태원 연관검색어 삭제 다르게 본 이유는?',
#  '대우전자-대유위니아, 제습기 시장 공략 본격화',
#  '원조 모바일 RPG명가 자존심 회복?..블레이드2 출시',
#  "가족기업 '머크'는 어떻게 350년을 계속했나",
#  '반도체 왕좌 앉은 삼성전자, 인텔과 격차 더 벌려',
#  '[제9회 퓨처ICT포럼] "IoT기기 제조 단계부터 적용할 보안 가이드라인 필요"',
#  '[제9회 퓨처ICT포럼] "IoT 단말기 고유기능만 가능한 \'머드폴리시\' 적용해야"',
#  '[인사]중소기업진흥공단',
#  '카카오M, 이병헌·공유 품고 해외로…BH엔터·숲엔터 등 지분 투자',
#  '한컴MDS, AI 기반 전시 안내 로봇 만든다',
#  '로봇카트·AI체험·5G통신…"4차산업혁명 온몸으로 느꼈다"',
#  '"AI 실생활에 빠르게 적용"…"데이터 확보없인 발전 한계"',
#  'AI면접관 "표정이 굳었군요"…가상면접 체험 구직자 `깜짝`',
#  '"규제장벽·인재난 절감한 1년"… 카카오브레인 CSO의 \'눈물\'',
#  '220兆 시장 선점 나선 中… 내년 5G 스마트폰 첫 출시',
#  '[2018 과학기술연차대회] 4차산업혁명 핵심 자율주행차 기술, 어느 수준?',
#  '\'현미경의 난시\' 고쳤다… "모든 광학·전파 장비 설계 바뀔 것"',
#  "'넘사벽' 카카오톡, 국내 모바일 메신저 점유율 94.4%",
#  '카카오M, 이병헌 소속사와 손 잡았다',
#  '의혹과 배신으로 얼룩진 ‘e불편한세상’',
#  "가민, 골퍼 위한 레이저 거리측정기 '어프로치Z80' 출시",
#  '[모바일한경] 멸종위기 눈표범을 살릴 수 있는 보드카 등',
#  '[단독] 美 "韓, 中과 5G·드론 기술협력 말라"',
#  '[제9회 퓨처ICT포럼] "5G, 20년간 10만개 마이크로산업 창출할 것"',
#  "[막오른 MWC] 6년간 85조 투자···시범도시 선정···중국 '5G 표준화' 주도권 잡아",
#  '[막오른 MWC] 5G 기술로 수술로봇·원격운전까지···황창규 "中 기술발전 예상 뛰어넘어"',
#  '[제9회 퓨처ICT포럼] "자율주행차, 역사상 가장 파괴적인 혁신"',
#  'KT, 해지한 휴대폰 번호 29일간 사용 금지',
#  '[제9회 퓨처ICT포럼] "4차산업혁명 꽃 피우려면 히든챔피언 기업이 선두에 서야"',
#  "[MWC 상하이]삼성 없이…화웨이·에릭슨·노키아 5G '각축'",
#  'KT, 다음달 2일부터 휴대폰 번호 재사용 ‘전면금지’',
#  "IT '주52시간' 급한 불 껐지만..'업무환경 열악' 선입견 우려도",
#  '화웨이 "내년 9월 5G폰 출시"…5G 장비 이어 단말기도 \'눈독\'(종합)',
#  '“해외서 한 ICO, 국내 자본시장법 적용 받을 수도”',
#  '[제9회 퓨처ICT포럼] 임현수 LG CNS 사원 "5G 기술로 스마트팩토리 실현, 힌트 얻었다"',
#  '[제9회 퓨처ICT포럼] "5G 시대, 상상 초월한 비즈니스 모델 쏟아져 나올 것"',
#  '피앤피시큐어 "15년간 성장..일본 이어 유럽도 진출"',
#  '[제9회 퓨처ICT포럼] "전세계 통신사, 5G 선뜻 못나선채 한국만 쳐다봐"',
#  '한컴지엠디, 드론 조종 자격증 교육용 VR시뮬레이터 개발',
#  '안랩, 금융권 대상 보안 전략 세미나 ‘ISF 스퀘어 2018’ 개최',
#  '한국후지쯔, 미래자판기연구소와 전략적 파트너십 체결',
#  '이통 3사, `동반성장지수 평가` 모두 `최우수`',
#  '웹젠, 자율근무제 도입..포괄임금제 전면 폐지',
#  "[원전 밸류체인이 무너진다] R&D도 '해체'에 집중..성능 향상엔 뒷전",
#  '"암호화폐 일정요건 갖춘 자율규제 바람직"',
#  '전자 영주권 도입...유럽 진출 꿈꾸는 글로벌 벤처 몰려',
#  '메디톡스, 지방분해 신약 개발 착수..."사업영역 확장"',
#  '[SMSC]"디지털 콘텐츠 성공 코드, B급이 지배"',
#  '[\'디지털 최강국\' 에스토니아 가보니]블록체인·빅데이터가 국가운영 OS..."e-ID 하나로 多돼요"',
#  '카카오M, 이병헌·공유·김태리 소속 연예기획사 투자',
#  "피파온라인4로 만든, 러시아 월드컵 2라운드 '베스트11'",
#  '광주 첨단 3지구에 AI 창업단지 조성한다…연구용역 추진',
#  "'스탯'으로 달라지는 카이저의 직업특성, 마법사 육성 방향은?",
#  "라이엇게임즈, 한국 문화 담은 '롤드컵 우승 스킨' 공개",
#  '유료방송 시장점유율 합산규제 일몰…시장 지각변동?',
#  '[핫클립]블랙핑크 뮤비에 감탄하는 외국인',
#  "카카오M, 이병헌·김태리 소속사 '지분투자', 협업체계 구축",
#  '폴 크루그먼 "한국 경제도 보복무역 전쟁에 노출"',
#  "'2018 대한민국과학기술연차대회 심포지엄'",
#  "'2018 대한민국과학기술연차대회 심포지엄'",
#  '스타벅스 과일 특성 그대로 담은 여름 음료 5종 출시',
#  '네이버 "광고비 최대 10만원까지 지원해드립니다"',
#  '페이스북, 암호화폐 광고 빗장 완화',
#  '[블록포스트] 디지털 아이디로 간편하게 입국..여권·비행기표가 필요없다',
#  '블록체인 창업의 요람 ‘해시드 라운지’ 오픈',
#  '삼성전자, 올 1분기 인텔과 격차 벌리며 세계 반도체 시장 1위 수성',
#  '대구창조경제혁신센터, "해외진출 원하는 스타트업, 대구로 오세요"',
#  "KT, 와이브로 철수 '급속 페달'",
#  "게임업계 '선택적 근로시간제' 확산…넷마블 넥슨 엔씨소프트 선도",
#  '한의학연구원 직원, 규정 어기고 진료행위하다 적발',
#  '[국제]“LG V40, 퀸터플 카메라 품는다”',
#  '이찬형 한국MSC소프트웨어 대표 "4차 혁명시대, 자율주행과 3D프린팅 시뮬레이션 시장 성장할 것"',
#  "[미래기업 포커스]유민에스티, 재사용 가능한 '화학용액 누설감지 센서' 개발",
#  '파워테크닉스, SiC 전력반도체 개발 명맥 잇는다',
#  "LG그룹, 4세대 경영 '구광모 대표이사' 체제 가동",
#  "[2018 상반기 인기상품]품질우수-LG전자 세탁기 '트롬 트윈워시'",
#  "[사설]원전 경쟁력 보여 준 '원자력 엑스포'",
#  '인스타그램으로 영상통화도 한다',
#  'LGU+, IoT활용 ‘스마트 플랜트’ 개발…한화토탈과 업무협약 체결',
#  "'오버워치', 추천 및 그룹 찾기 도입",
#  "'페이트/그랜드 오더', 레이드 퀘스트 라쇼몽 실시",
#  '웹젠, 자율출근제 시행 및 포괄임금제 폐지',
#  '"블록체인 열기는 거품" 애플 공동 창업자도 경고',
#  "'열혈강호 for kakao', 아시아 챔피언십 2018 7월 29일 개최",
#  '세계 종말 그린 슈팅 RPG ‘뉴본’, “손맛은 기본…스토리 일치성 높였다”',
#  '‘페이트 그랜드오더’ 첫 레이드 이벤트 ‘라쇼몽’ 실시',
#  '모바일 리듬게임 ‘뱅드림’, 여자친구 히트곡 ‘밤’ 추가',
#  '‘영원한 7일의 도시’ 28일 출시…사전 다운로드 시작',
#  '2018 인사이드 3D프린팅 컨퍼런스&엑스포 개막',
#  '오라클, 자바SE 월 구독 상품 출시...칩당 25달러',
#  '과기정통부, 일자리창출 지원에 700억 원 특구펀드 조성',
#  '한국지역정보개발원, 정보화마을 교육봉사자 양성교육 실시',
#  '강제참석 같지만 회식 근로시간 X, 체육대회 O···기준은',
#  "SKT·KT 5G 기술 국제 무대에서 호평, LGU+ '내실 다지기' 주력",
#  '산림청, 국민과 친근한 ‘수목장림’…2022년까지 50곳 조성',
#  '중기부, 국내 중소기업 `중국 동북3성` 진출 토대 다져',
#  '‘글로벌 바이오 콘퍼런스’ 개막...32개국서 3000명 참석',
#  '보령바이오, 임신성 질환 유전적 위험 예측 서비스 출시',
#  '대웅제약, 바이오시밀러 ‘삼페넷’ 심포지엄 개최...임상정보 공유']
