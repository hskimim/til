# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pylab as plt
import statsmodels.api as sm
import matplotlib as mpl

# %%
from scipy.cluster.hierarchy import linkage, dendrogram
np.set_printoptions(precision=5, suppress=True) 

np.random.seed(4711)  # for repeatability of this tutorial
a = np.random.multivariate_normal([10, 0], [[3, 1], [1, 4]], size=[100,])
b = np.random.multivariate_normal([0, 20], [[3, 1], [1, 4]], size=[50,])
X = np.concatenate((a, b),)
print(X.shape)

plt.scatter(X[:,0], X[:,1], s=50)
plt.show()
# Out:
# (150, 2)

# %%
Z = linkage(X, 'ward')
Z
# Out:
# array([[ 52.     ,  53.     ,   0.04151,   2.     ],
#        [ 14.     ,  79.     ,   0.05914,   2.     ],
#        [ 33.     ,  68.     ,   0.07107,   2.     ],
#        [ 17.     ,  73.     ,   0.07137,   2.     ],
#        [  1.     ,   8.     ,   0.07543,   2.     ],
#        [ 85.     ,  95.     ,   0.10928,   2.     ],
#        [108.     , 131.     ,   0.11007,   2.     ],
#        [  9.     ,  66.     ,   0.11302,   2.     ],
#        [ 15.     ,  69.     ,   0.11429,   2.     ],
#        [ 63.     ,  98.     ,   0.1212 ,   2.     ],
#        [107.     , 115.     ,   0.12167,   2.     ],
#        [ 65.     ,  74.     ,   0.1249 ,   2.     ],
#        [ 58.     ,  61.     ,   0.14028,   2.     ],
#        [ 62.     , 152.     ,   0.1726 ,   3.     ],
#        [ 41.     , 158.     ,   0.1779 ,   3.     ],
#        [ 10.     ,  83.     ,   0.18635,   2.     ],
#        [114.     , 139.     ,   0.20419,   2.     ],
#        [ 39.     ,  88.     ,   0.20628,   2.     ],
#        [ 70.     ,  96.     ,   0.21931,   2.     ],
#        [ 46.     ,  50.     ,   0.22049,   2.     ],
#        [109.     , 113.     ,   0.22499,   2.     ],
#        [ 31.     ,  80.     ,   0.23286,   2.     ],
#        [ 22.     , 150.     ,   0.23608,   3.     ],
#        [ 28.     ,  35.     ,   0.24282,   2.     ],
#        [ 18.     ,  34.     ,   0.24839,   2.     ],
#        [105.     , 137.     ,   0.25928,   2.     ],
#        [ 21.     ,  71.     ,   0.262  ,   2.     ],
#        [  3.     ,  32.     ,   0.26651,   2.     ],
#        [123.     , 145.     ,   0.27191,   2.     ],
#        [ 11.     ,  44.     ,   0.2914 ,   2.     ],
#        [ 76.     ,  99.     ,   0.29709,   2.     ],
#        [ 47.     ,  59.     ,   0.29906,   2.     ],
#        [  5.     ,  91.     ,   0.3392 ,   2.     ],
#        [ 90.     , 181.     ,   0.33976,   3.     ],
#        [124.     , 143.     ,   0.34521,   2.     ],
#        [ 43.     ,  55.     ,   0.34593,   2.     ],
#        [ 51.     ,  64.     ,   0.34655,   2.     ],
#        [ 54.     ,  97.     ,   0.35581,   2.     ],
#        [  2.     ,  93.     ,   0.37556,   2.     ],
#        [100.     , 160.     ,   0.38091,   3.     ],
#        [ 12.     ,  78.     ,   0.40147,   2.     ],
#        [118.     , 133.     ,   0.4051 ,   2.     ],
#        [ 26.     , 167.     ,   0.41213,   3.     ],
#        [ 82.     , 163.     ,   0.41898,   4.     ],
#        [ 25.     , 223.     ,   1.17325,   5.     ],
#        [ 36.     , 180.     ,   1.18423,   3.     ],
#        [185.     , 216.     ,   1.19546,   6.     ],
#        [211.     , 224.     ,   1.22482,   4.     ],
#        [140.     , 225.     ,   1.32626,   3.     ],
#        [138.     , 207.     ,   1.35046,   4.     ],
#        [161.     , 222.     ,   1.49318,   4.     ],
#        [194.     , 197.     ,   1.49619,   8.     ],
#        [220.     , 239.     ,   1.59175,   9.     ],
#        [215.     , 231.     ,   1.6701 ,   6.     ],
#        [129.     , 141.     ,   1.6758 ,   2.     ],
#        [201.     , 251.     ,   1.699  ,   6.     ],
#        [204.     , 240.     ,   1.70929,   9.     ],
#        [ 27.     ,  60.     ,   1.75073,   2.     ],
#        [213.     , 228.     ,   1.79407,   7.     ],
#        [227.     , 233.     ,   1.84758,   7.     ],
#        [120.     , 234.     ,   1.88067,   4.     ],
#        [208.     , 255.     ,   1.92114,  10.     ],
#        [235.     , 249.     ,   2.03403,   8.     ],
#        [219.     , 237.     ,   2.15902,   6.     ],
#        [125.     , 250.     ,   2.23528,   4.     ],
#        [232.     , 246.     ,   2.26166,   8.     ],
#        [221.     , 245.     ,   2.42437,  10.     ],
#        [241.     , 257.     ,   2.46289,  12.     ],
#        [218.     , 253.     ,   2.48409,  14.     ],
#        [229.     , 248.     ,   2.61009,   9.     ],
#        [217.     , 244.     ,   2.75678,   5.     ],
#        [127.     , 262.     ,   2.83419,   5.     ],
#        [  4.     , 259.     ,   3.10981,   3.     ],
#        [242.     , 261.     ,   3.32706,   9.     ],
#        [236.     , 271.     ,   3.48016,  12.     ],
#        [182.     , 267.     ,   3.72097,  10.     ],
#        [247.     , 268.     ,   3.83145,  13.     ],
#        [243.     , 260.     ,   4.003  ,  10.     ],
#        [238.     , 256.     ,   4.03585,   6.     ],
#        [264.     , 273.     ,   4.11676,  13.     ],
#        [252.     , 265.     ,   4.17761,  10.     ],
#        [254.     , 263.     ,   5.05391,  19.     ],
#        [258.     , 276.     ,   5.31023,  21.     ],
#        [269.     , 272.     ,   6.20388,  17.     ],
#        [270.     , 283.     ,   6.44512,  33.     ],
#        [279.     , 281.     ,   6.5936 ,  23.     ],
#        [274.     , 275.     ,   6.65622,  12.     ],
#        [ 40.     , 278.     ,   7.11106,  14.     ],
#        [277.     , 288.     ,   7.86879,  22.     ],
#        [266.     , 280.     ,   8.04935,  10.     ],
#        [285.     , 291.     ,   8.74822,  27.     ],
#        [282.     , 289.     ,   9.84428,  24.     ],
#        [284.     , 286.     ,  12.42735,  54.     ],
#        [290.     , 294.     ,  15.11533,  76.     ],
#        [287.     , 292.     ,  17.11527,  50.     ],
#        [293.     , 295.     ,  23.12199, 100.     ],
#        [296.     , 297.     , 180.27043, 150.     ]])

# %%
mpl.rcParams["font.family"] = 'DejaVu Sans'
plt.figure(figsize=(10,30))
ax = plt.subplot(111)
dendrogram(Z, leaf_font_size=10, orientation='right')
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('sample index')
plt.ylabel('distance')
ax.set_xlim(xmin=0.03)
ax.set_xscale('log')
plt.show()

# %%
from numpy.random import randn

n_samples = 500

mu1 = np.array([0, 0])
mu2 = np.array([-6, 3])
sigma1 = np.array([[0., -0.1], [1.7, .4]])
sigma2 = np.eye(2)

np.random.seed(0)
X = np.r_[1.0 * np.dot(randn(n_samples, 2), sigma1) + mu1,
          0.7 * np.dot(randn(n_samples, 2), sigma2) + mu2,
         ]
plt.scatter(X[:, 0], X[:, 1], s=5)
plt.show()

# %%
from sklearn.mixture import GaussianMixture

# %%
model = GaussianMixture(n_components=2, init_params='random', random_state=0, max_iter=1)
model.fit(X)
# Out:
# /home/hskimim/anaconda3/lib/python3.6/site-packages/sklearn/mixture/base.py:237: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   % (init + 1), ConvergenceWarning)
# GaussianMixture(covariance_type='full', init_params='random', max_iter=1,
#         means_init=None, n_components=2, n_init=1, precisions_init=None,
#         random_state=0, reg_covar=1e-06, tol=0.001, verbose=0,
#         verbose_interval=10, warm_start=False, weights_init=None)

# %%
gamma = model.predict_proba(X)

# %%
plt.scatter(X[:, 0], X[:, 1], s=50, linewidth=1, edgecolors="b", cmap=plt.cm.binary, c=gamma[:, 0])
plt.show()

# %%
def plot_gaussianmixture(n, k=10):
    model = GaussianMixture(n_components=2, init_params='random', random_state=1, tol=1e-9, max_iter=n)
    model.fit(X)
    gamma = model.predict_proba(X)
    plt.scatter(X[:, 0], X[:, 1], s=50, linewidth=1, edgecolors="b", cmap=plt.cm.binary, c=gamma[:, 0])
    plt.show()
    return model

# %%
plot_gaussianmixture(5);
# Out:
# /home/hskimim/anaconda3/lib/python3.6/site-packages/sklearn/mixture/base.py:237: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   % (init + 1), ConvergenceWarning)

# %%
plot_gaussianmixture(10);
# Out:
# /home/hskimim/anaconda3/lib/python3.6/site-packages/sklearn/mixture/base.py:237: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   % (init + 1), ConvergenceWarning)

# %%
plot_gaussianmixture(15);
# Out:
# /home/hskimim/anaconda3/lib/python3.6/site-packages/sklearn/mixture/base.py:237: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   % (init + 1), ConvergenceWarning)

# %%
plot_gaussianmixture(20);

# %%
from hmmlearn import hmm
np.random.seed(3)

model = hmm.GaussianHMM(n_components=2, covariance_type="diag")
model.startprob_ = np.array([0.9, 0.1])
model.transmat_ = np.array([[0.95, 0.05],[0.15, 0.85]])
model.means_ = np.array([[1.0], [-3.0]])
model.covars_ = np.array([[15.0], [40.0]])
X, Z = model.sample(500)

# %%
plt.subplot(311)
plt.plot(X)
plt.title("random variable")
plt.subplot(312)
plt.plot(Z)
plt.title("discrete state")
plt.subplot(313)
plt.plot((1 + 0.01*X).cumprod())
plt.title("X cumulated")
plt.tight_layout()
plt.show()

# %%
sns.distplot(X)
plt.show()
# Out:
# /home/hskimim/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
model2 = hmm.GaussianHMM(n_components=2, n_iter=len(X)).fit(X)
model2

# %%
Z_hat = model2.decode(X)[1]
X_cum = (1 + 0.01*X).cumprod()
X_cum_hat = X_cum.copy()
X_cum_hat[Z_hat == 0] = np.nan
# Out:
# /home/hskimim/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:77: DeprecationWarning: Function log_multivariate_normal_density is deprecated; The function log_multivariate_normal_density is deprecated in 0.18 and will be removed in 0.20.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
plt.subplot(211)
plt.plot(X_cum, lw=5)
plt.plot(X_cum_hat, 'r-', lw=5)
plt.title("X cumulated")
plt.subplot(212)
plt.plot(Z, 'bo-')
plt.plot(Z_hat, 'ro-')
plt.title("discrete state")
plt.tight_layout()
plt.show()
